# %% [markdown]
# > ### EEE4423: Deep Learning Lab
#
# # LAB \#6: Semantic Segmentation

# %%
import datetime
print("This code is written at " + str(datetime.datetime.now()))
# Out:
# This code is written at 2023-04-12 15:24:59.535905

# %%
import cv2
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.optim as optim

import torchvision.models as models

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### What is Semantic Segmentation?
# #### Semantic segmentation is an approach to understand what is in the image in pixel-level:
#
# - It is a lot more difficult than image classification, which makes a prediction in image-level.
#
# - It differs from object detection in that it has no information about instances.
#
# <img src="https://drive.google.com/uc?export=view&id=1aR-RSJCsSEROjmQych61RbIhBul9cqA1" alt="no_image" style="width: 900px;"/>
#
# Applications for semantic segmentation include:
#
# - Autonomous driving
#
# - Image Editing
#
# - Classification of terrain visible in satellite imagery
#
# - Medical imaging analysis
#
# ### 1. Semantic segmentation with CNNs
# - Typical classification models (AlexNet, VGGNet, ...) take fixed-sized inputs and produce a probability vector. The fully connected layers of these models have fixed dimensions and throw away spatial coordinates.
#
#
# - It is known that the fully connected layer can be viewed as a convolution layer with a kernel that covers only one pixel, that is, a 1x1 kernel. Thus, we can convert the fully connected layers into convolution layers with maintaining pre-trained weights.
#
#
# - After 'convolutionalizing' fully connected layers, a feature map needs to be upsampled because of pooling operations in the models. Instead of using simple bilinear interpolation, we can use a transposed convolution layer to learn the interpolation process. This layer is also called as upconvolution, deconvolution or fractionally-strided convolution.

# %% [markdown]
# ### 1.1 Pixel wise classification using sliding window

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1l2-Degy7LpK20NbooHosRV8NzeRvNdPd" alt="no_image" style="width: 900px;"/>

# %% [markdown]
# ### 1.1.1 Example with VGG-Net

# %% [markdown]
# **Load a test image**

# %%
cd /root
# Out:
# /root

# %%
from PIL import Image
test_img_path = './dataset-dllab/lab06/img/2009_005160.jpg'
test_img = Image.open(test_img_path)
test_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x370 at 0x7F724C1FCBA8>

# %% [markdown]
# **Standardization of the test image**

# %%
import torchvision.transforms as transforms
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    normalize,
])

test_transform = transform(test_img).cuda().unsqueeze(0)
print(test_transform.size())
# Out:
# torch.Size([1, 3, 224, 224])

# %% [markdown]
# **Load VGG-Net**

# %%
import torchvision.models.vgg as vgg
imageNet = vgg.vgg16(pretrained=True).cuda()

# %%
import torch
import torch.nn as nn
with torch.no_grad():
    out = imageNet(test_transform)

out_class = torch.argmax(out)
print(out.size())
print(out_class) # 285 is egyptian cat in ImageNet
# Out:
# torch.Size([1, 1000])
# tensor(285, device='cuda:0')

# %%
# padding
m = nn.ZeroPad2d((111,112,111,112))
pad_image = m(test_transform)
res = torch.zeros((224,224)).cuda()

# %%
# sliding window approach for segmentation
# NOTICE: It takes some time
for i in range(224):
    for j in range(224):
        patch = pad_image[:,:,i:i+224,j:j+224]
        # classify each pixels
        with torch.no_grad():
            res[i,j] = torch.argmax(imageNet(patch))

# %%
print(res, "\n",res.shape)
# Out:
# tensor([[285., 285., 285.,  ..., 282., 282., 285.],
#         [285., 285., 285.,  ..., 282., 285., 285.],
#         [285., 285., 285.,  ..., 282., 281., 285.],
#         ...,
#         [285., 299., 360.,  ..., 254., 254., 254.],
#         [286., 285., 285.,  ..., 254., 254., 254.],
#         [284., 286., 286.,  ..., 280., 738., 254.]], device='cuda:0')
#  torch.Size([224, 224])

# %% [markdown]
# **Visualize the output, classified as 'egyptian cat' (285)**

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.subplot(1,2,1)
plt.imshow(test_transform[0].data.cpu().numpy().transpose((1,2,0)))
plt.subplot(1,2,2)
plt.imshow((res==285).data.cpu().numpy()) # Visualize pixels classified as egyptian cat
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# - Inefficient & Ineffective !

# %% [markdown]
# ### 1.2 Pixel wise classification using image classification

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1sWibO6xfau_kfWt-2T_rh_ARrzsR4PRV" alt="no_image" style="width: 900px;"/>

# %% [markdown]
# #### 1.2.1 Convolutional VGG

# %%
import torchvision.models as models

class ConvolutionalVGG(nn.Module):
    def __init__(self):
        super(ConvolutionalVGG, self).__init__()
        self.features = models.vgg16(pretrained=True).features

        # fc6
        self.fc6 = nn.Conv2d(512, 4096, 7)
        self.relu6 = nn.ReLU(inplace=True)
        self.drop6 = nn.Dropout2d()

        # fc7
        self.fc7 = nn.Conv2d(4096, 4096, 1)
        self.relu7 = nn.ReLU(inplace=True)
        self.drop7 = nn.Dropout2d()
        
        # fc8
        self.fc8 = nn.Conv2d(4096, 1000, 1)
        
        self.copy_params_from_vgg16()

    def forward(self, x):
        conv5 = self.features(x)

        fc6 = self.relu6(self.fc6(conv5))
        fc7 = self.drop6(fc6)

        fc7 = self.relu7(self.fc7(fc7))
        fc8 = self.drop7(fc7)
        
        score = self.fc8(fc8)

        return score

    def copy_params_from_vgg16(self):
        vgg16 = models.vgg16(pretrained=True)
        for i, name in zip([0, 3, 6], ['fc6', 'fc7', 'fc8']):
            l1 = vgg16.classifier[i]
            l2 = getattr(self, name)
            l2.weight.data.copy_(l1.weight.data.view(l2.weight.size()))
            l2.bias.data.copy_(l1.bias.data.view(l2.bias.size()))

# %%
conv_vgg = ConvolutionalVGG().cuda()
conv_vgg
# Out:
# ConvolutionalVGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc6): Conv2d(512, 4096, kernel_size=(7, 7), stride=(1, 1))
#   (relu6): ReLU(inplace=True)
#   (drop6): Dropout2d(p=0.5, inplace=False)
#   (fc7): Conv2d(4096, 4096, kernel_size=(1, 1), stride=(1, 1))
#   (relu7): ReLU(inplace=True)
#   (drop7): Dropout2d(p=0.5, inplace=False)
#   (fc8): Conv2d(4096, 1000, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
transform_conv = transforms.Compose([
    transforms.ToTensor(),
    normalize,
])

# %%
test_conv = transform_conv(test_img).cuda().unsqueeze(0)
print(test_conv.size())
# Out:
# torch.Size([1, 3, 370, 500])

# %%
conv_out = conv_vgg(test_conv)
pred = torch.argmax(conv_out, dim=1)
print(pred,"\n",pred.shape)
# Out:
# tensor([[[285, 284, 284, 284, 284, 284, 285, 285, 285],
#          [284, 284, 284, 284, 284, 287, 285, 285, 285],
#          [904, 284, 284, 284, 284, 285, 285, 285, 285],
#          [904, 284, 284, 284, 284, 620, 284, 284, 285],
#          [285, 285, 284, 285, 285, 285, 285, 285, 285]]], device='cuda:0')
#  torch.Size([1, 5, 9])

# %% [markdown]
# Well...
#
# Although modifying VGG-Net to fully convolutional network results in a pixel-wise ouput, the output resolution is smaller than the original image resolution. Moreover, we can see that many pixels are misclassified (i.e., not 285).

# %% [markdown]
# #### 1.2.2 Add simple upsampling layer (Bilinear) and retrain with PASCAL VOC 2012  [1 point]
# - Re-define the last layer so as to classify classes in the PASCAL VOC datasets
# - Use bilinear interpolation to make the network output equal to the input size

# %%
import torchvision.models as models

class ConvolutionalVGGwithUpsample(nn.Module):
    def __init__(self):
        super(ConvolutionalVGGwithUpsample, self).__init__()
        self.features = models.vgg16(pretrained=True).features
        self.features[0].padding = (100,100)
        
        # fc6
        self.fc6 = nn.Conv2d(512, 4096, 7)
        self.relu6 = nn.ReLU(inplace=True)
        self.drop6 = nn.Dropout2d()

        # fc7
        self.fc7 = nn.Conv2d(4096, 4096, 1)
        self.relu7 = nn.ReLU(inplace=True)
        self.drop7 = nn.Dropout2d()

        # fc8  
        #############
        # CODE HERE #
        #############
        self.fc8 = nn.Conv2d(4096,21,1)
        self.copy_params_from_vgg16()
        

    def forward(self, x):
        conv5 = self.features(x)

        fc6 = self.relu6(self.fc6(conv5))
        fc7 = self.drop6(fc6)
        
        score = self.fc8(fc7)
        
        
        
        #############
        # CODE HERE #
        #############
        score = nn.Upsample(size =x.shape[-2:],mode = 'bilinear')(score)
        
        
        return score

    def copy_params_from_vgg16(self):
        vgg16 = models.vgg16(pretrained=True)
        for i, name in zip([0, 3], ['fc6', 'fc7']):
            l1 = vgg16.classifier[i]
            l2 = getattr(self, name)
            l2.weight.data.copy_(l1.weight.data.view(l2.weight.size()))
            l2.bias.data.copy_(l1.bias.data.view(l2.bias.size()))

# %%
conv_vgg_upsample = ConvolutionalVGGwithUpsample().cuda()

# %%
#decoding the label to color feature!
def decode_labels(mask, num_classes=21):
    from PIL import Image         
    label_colours = [(0, 0, 0)
                 # 0=background
                 , (128, 0, 0), (0, 128, 0), (128, 128, 0), (0, 0, 128), (128, 0, 128)
                 # 1=aeroplane, 2=bicycle, 3=bird, 4=boat, 5=bottle
                 , (0, 128, 128), (128, 128, 128), (64, 0, 0), (192, 0, 0), (64, 128, 0)
                 # 6=bus, 7=car, 8=cat, 9=chair, 10=cow
                 , (192, 128, 0), (64, 0, 128), (192, 0, 128), (64, 128, 128), (192, 128, 128)
                 # 11=diningtable, 12=dog, 13=horse, 14=motorbike, 15=person
                 , (0, 64, 0), (128, 64, 0), (0, 192, 0), (128, 192, 0), (0, 64, 128)]
                 # 16=potted plant, 17=sheep, 18=sofa, 19=train, 20=tv/monitor
        
    h, w = mask.shape

    img = Image.new('RGB', (w, h))
    pixels = img.load()
    for j_, j in enumerate(mask[:, :]):
        for k_, k in enumerate(j):
            if k < num_classes:
                pixels[k_, j_] = label_colours[k]
    output = np.array(img)

    return output

# %%
model_data = torch.load('./pretrain/lab06/vgg_conv_upsample.pth')
conv_vgg_upsample.load_state_dict(model_data)
# Out:
# <All keys matched successfully>

# %%
with torch.no_grad():
    conv_out = conv_vgg_upsample(test_conv)
output = torch.argmax(conv_out, dim=1)

vis_output = decode_labels(output[0].data.cpu().numpy())

# %%
plt.subplot(1,2,1)
plt.imshow(test_conv[0].data.cpu().numpy().transpose((1,2,0)))
plt.subplot(1,2,2)
plt.imshow(vis_output)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### 1.3 Upsampling method with CNNs

# %% [markdown]
# #### 1.3.1 Transposed Convolution
#
# <img src="https://drive.google.com/uc?export=view&id=1IfoOAei35ydfeWu5qlXhZwNnW8cy_tJn"  onerror="this.style.display='none'" /><br><br>
#
#
# - The transposed convolution (it is often called as "deconvolution") is used to up-sample the input resolution by using learnable filters. In contrast to the standard convolution, which aggregates spatial information to a single point, it spreads a point of the input over multiple spatial locations.
# - For example, a $3\times3$ kernel with a stride of 2 converts the~$2\times2$~(cyan squares) input into the~$5\times5$~(blue squares) output.

# %% [markdown]
# #### 1.3.2 Dilated Convolution
# <img src="https://drive.google.com/uc?export=view&id=1DCDuj_6IhA8HdZzE8OZkrYIuDeevtjKV"  onerror="this.style.display='none'" /><br><br>
#
# - The dilated convolution introduces 'a dilation rate' to the standard convolution.
#
# - The dilation rate means a spacing value between elements of a kernel, which enlarges the receptive field without introducing additional parameters.
#
# - For example, a $3\times3$ kernel with a dilation rate of 2 has the same receptive field as a $5\times5$ kernel while it still use 9 parameters only, compared to the $5\times5$ the uses 25 parameters.

# %% [markdown]
# ## 2. [Lab] Semantic segmentation

# %% [markdown]
# ### 2.1 Write a FCN8s model  [4 points]

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1icsmWH1-N_g90VJOg7zyIFVec-TmPscA"  onerror="this.style.display='none'" /><br><br>
#
# <p style='text-align:right;'>[<a href='https://medium.com/@wilburdes/semantic-segmentation-using-fully-convolutional-neural-networks-86e45336f99b'>source</a>]</p>

# %% [markdown]
# **Crop boundary example**

# %%
a = torch.ones((1, 1, 160, 140))
b = torch.ones((1, 1, 120, 120))

try:
    a + b
except:
    print('The size of tensors are different')
    print(a.size())
    print(b.size())
    
# crop boundary 
a = a[:, :, 5: 5+b.size(2), 5:5+b.size(3)]

# add connection with weight
c = 0.01*a + b
# Out:
# The size of tensors are different
# torch.Size([1, 1, 160, 140])
# torch.Size([1, 1, 120, 120])

# %% [markdown]
# - Predict 1: $1\times1$ Conv(in: 4096, out: n_class)
# - Predict 2: $1\times1$ Conv(in: 512, out: n_class), weight = 0.01
# - Predict 3: $1\times1$ Conv(in: 256, out: n_class), weight = 0.0001
#
# - Deconv 1: $4\times4$ Transposed Conv (in: n_class, out: n_class, stride: 2, biase: False)
# - Deconv 2: $4\times4$ Transposed Conv (in: n_class, out: n_class, stride: 2, biase: False)
# - Deconv 3: $16\times16$ Transposed Conv (in: n_class, out: n_class, stride: 8, biase: False)

# %%
class FCN8s(nn.Module):
    def __init__(self, n_class=21):
        super(FCN8s, self).__init__()
        # VGG features
        self.features = models.vgg16(pretrained=True).features
        
        # fc6
        self.fc6 = nn.Conv2d(512, 4096, 7)
        self.relu6 = nn.ReLU(inplace=True)
        self.drop6 = nn.Dropout2d()

        # fc7
        self.fc7 = nn.Conv2d(4096, 4096, 1)
        self.relu7 = nn.ReLU(inplace=True)
        self.drop7 = nn.Dropout2d()
        
        #############
        # CODE HERE #
        ############# 
        #
        self.pred1 = nn.Conv2d(4096, n_class,1)
        self.pred2 = nn.Conv2d(512, n_class,1)
        self.pred3 = nn.Conv2d(256, n_class,1)
        
        self.deconv1 =nn.ConvTranspose2d(n_class,n_class,kernel_size = 4, stride =2, bias = False)  # i
        self.deconv2 =nn.ConvTranspose2d(n_class,n_class,kernel_size = 4, stride =2, bias = False)  # 
        self.deconv3 =nn.ConvTranspose2d(n_class,n_class,kernel_size = 16, stride =8, bias = False) # 
        
        ####
        
        self._initialize_weights()
        self.copy_params_from_vgg16()

    def _initialize_weights(self):
        self.features[0].padding = (100,100)
        
        for m in self.modules():
            if isinstance(m, nn.MaxPool2d):
                m.ceil_mode=True
            if isinstance(m, nn.ConvTranspose2d):
                assert m.kernel_size[0] == m.kernel_size[1]
                initial_weight = get_upsampling_weight(
                    m.in_channels, m.out_channels, m.kernel_size[0])
                m.weight.data.copy_(initial_weight)

    def forward(self, x):
        #############
        # CODE HERE #
        ############# 
        pool3 = self.features[:17](x) # i
        pool4 = self.features[17:24](pool3) #
        pool5 = self.features[24:](pool4) 
        
        pred1 = self.drop6(self.relu6(self.fc6(pool5)))
        pred1 = self.drop7(self.relu7(self.fc7(pred1))) # i-> i // 32
        # prediction results(21 classes)
        pred1 = self.pred1(pred1)
        pred2 = self.pred2(pool4)
        pred3 = self.pred3(pool3)
        
        # Upsample
        deconv1 = self.deconv1(pred1)
        
        # Middle Crop Index 
        crop_w = (pred2.shape[2] - deconv1.shape[2]) // 2
        crop_h = (pred2.shape[3] - deconv1.shape[3]) // 2
        # Skip conection with weight 0.01 -> Upsample
        deconv2 = self.deconv2(deconv1 + 0.01* pred2[:,:,crop_w:crop_w+deconv1.shape[2],crop_h:crop_h+deconv1.shape[3]])
        # Middle Crop Index
        crop_w = (pred3.shape[2] - deconv2.shape[2]) // 2
        crop_h = (pred3.shape[3] - deconv2.shape[3]) // 2
        # Skip connection with weight 0.0001 -> Upsample
        deconv3 = self.deconv3(deconv2 + 0.0001*pred3[:,:,crop_w:crop_w+deconv2.shape[2], crop_h:crop_h+deconv2.shape[3]] )
        # Middle Crop Index
        crop_w = (deconv3.shape[2] - x.shape[2]) // 2
        crop_h = (deconv3.shape[3] - x.shape[3]) // 2
        x = deconv3[:,:,crop_w:crop_w+x.shape[2],crop_h:crop_h+ x.shape[3]]
        
        return x

    def copy_params_from_vgg16(self):
        vgg16 = models.vgg16(pretrained=True)
        for i, name in zip([0, 3], ['fc6', 'fc7']):
            l1 = vgg16.classifier[i]
            l2 = getattr(self, name)
            l2.weight.data.copy_(l1.weight.data.view(l2.weight.size()))
            l2.bias.data.copy_(l1.bias.data.view(l2.bias.size()))
            
def get_upsampling_weight(in_channels, out_channels, kernel_size):
    factor = (kernel_size + 1) // 2
    if kernel_size % 2 == 1:
        center = factor - 1
    else:
        center = factor - 0.5
    og = np.ogrid[:kernel_size, :kernel_size]
    filt = (1 - abs(og[0] - center) / factor) * \
           (1 - abs(og[1] - center) / factor)
    weight = np.zeros((in_channels, out_channels, kernel_size, kernel_size),
                      dtype=np.float64)
    weight[range(in_channels), range(out_channels), :, :] = filt
    return torch.from_numpy(weight).float()

# %%
model = FCN8s().cuda()

# %% [markdown]
# **Data Loader functions**

# %%
import random
import os

def read_file(path_to_file):
    with open(path_to_file) as f:
        img_list = []
        for line in f:
            img_list.append(line[:-1])
    return img_list

def chunker(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def flip(I, flip_p):
    if flip_p > 0.5:
        return np.fliplr(I)
    else:
        return I

def scale_im(img_temp, scale):
    new_dims = (int(img_temp.shape[0] * scale), int(img_temp.shape[1] * scale))
    return cv2.resize(img_temp, new_dims).astype(float)


def get_data(chunk, gt_path='/root/dataset-dllab/lab06/gt', img_path='/root/dataset-dllab/lab06/img'):
    assert len(chunk) == 1

    scale = random.uniform(0.5, 1.3)
    flip_p = random.uniform(0, 1)

    images = cv2.imread(os.path.join(img_path, chunk[0] + '.jpg')).astype(float)

    images = cv2.resize(images, (321, 321)).astype(float)
    images = scale_im(images, scale)
    images[:, :, 0] = images[:, :, 0] - 104.008
    images[:, :, 1] = images[:, :, 1] - 116.669
    images[:, :, 2] = images[:, :, 2] - 122.675
    images = flip(images, flip_p)
    images = images[:, :, :, np.newaxis]
    images = images.transpose((3, 2, 0, 1))
    images = torch.from_numpy(images.copy()).float()

    gt = cv2.imread(os.path.join(gt_path, chunk[0] + '.png'))[:, :, 0]
    gt[gt == 255] = 0
    gt = flip(gt, flip_p)

    dim = int(321 * scale)

    gt = cv2.resize(gt, (dim, dim), interpolation=cv2.INTER_NEAREST).astype(float)
    
    labels = gt[np.newaxis, :].copy()

    return images, labels

# %% [markdown]
# **Data load**

# %%
img_list = read_file('/root/dataset-dllab/lab06/list/train_aug.txt')
data_list = []

for i in range(10):
    np.random.shuffle(img_list)
    data_list.extend(img_list)
data_gen = chunker(data_list, 1)

# %%
lr =  0.00001  # choose your lr

optimizer = optim.Adam(model.parameters(), lr=lr)
optimizer.zero_grad()
max_iter = 20000

# %% [markdown]
# ### 2.2 Write train code and print loss [2 points]
# - Use a cross-entropy loss.
# - Print a training loss for every 100 iterations.
# - Show that the training loss steadily decreases.

# %%
def loss_calc(out, label):
    #############
    # CODE HERE #
    ############# 
    return nn.CrossEntropyLoss()(out,label)

# %%
# Mycrop + learning rate = 0.00001
running_loss = 0.0

model.train()
loss = 0.0
minimum_loss = 0.5
device = torch.device("cuda")
for iter in range(1,max_iter + 1):
    inputs, label = get_data(next(data_gen))
    
    #############
    # CODE HERE #
    ############# 
    optimizer.zero_grad()
    
    inputs = inputs.to(device)
    label = torch.tensor(label,dtype = torch.int64).to(device)
    
    pred = model(inputs)
    
    loss = loss_calc(pred.reshape(pred.shape[0],pred.shape[1], -1),label.reshape(label.shape[0],-1))
    
    running_loss += loss
    loss.backward()
    
    optimizer.step()
    
    if iter % 100 == 0:
        # save best model
        if running_loss/100 < minimum_loss:
            minimum_loss =running_loss/100
            torch.save({'state_dict':model.state_dict()},'/root/pretrain/weights/lab06/fcn.pkl')
        print (f"Iteration: {iter}, Loss: {running_loss/100:.6f}")
        running_loss = 0
        loss = 0
# Out:
# Iteration: 100, Loss: 2.487080
# Iteration: 200, Loss: 1.730298
# Iteration: 300, Loss: 1.389660
# Iteration: 400, Loss: 1.478842
# Iteration: 500, Loss: 1.245481
# Iteration: 600, Loss: 1.208036
# Iteration: 700, Loss: 1.168962
# Iteration: 800, Loss: 1.325465
# Iteration: 900, Loss: 1.191609
# Iteration: 1000, Loss: 1.053578
# Iteration: 1100, Loss: 1.170555
# Iteration: 1200, Loss: 1.222981
# Iteration: 1300, Loss: 1.092891
# Iteration: 1400, Loss: 1.094387
# Iteration: 1500, Loss: 0.995578
# Iteration: 1600, Loss: 0.922314
# Iteration: 1700, Loss: 0.922267
# Iteration: 1800, Loss: 0.926362
# Iteration: 1900, Loss: 1.092214
# Iteration: 2000, Loss: 0.946398
# Iteration: 2100, Loss: 0.849395
# Iteration: 2200, Loss: 0.954954
# Iteration: 2300, Loss: 0.911206
# Iteration: 2400, Loss: 1.041342
# Iteration: 2500, Loss: 0.896438
# Iteration: 2600, Loss: 0.980513
# Iteration: 2700, Loss: 0.856411
# Iteration: 2800, Loss: 0.799197
# Iteration: 2900, Loss: 0.938116
# Iteration: 3000, Loss: 0.903261
# Iteration: 3100, Loss: 0.933973
# Iteration: 3200, Loss: 0.801677
# Iteration: 3300, Loss: 0.890782
# Iteration: 3400, Loss: 0.801970
# Iteration: 3500, Loss: 0.820002
# Iteration: 3600, Loss: 0.759386
# Iteration: 3700, Loss: 0.799450
# Iteration: 3800, Loss: 0.661426
# Iteration: 3900, Loss: 0.696284
# Iteration: 4000, Loss: 0.900253
# Iteration: 4100, Loss: 0.830007
# Iteration: 4200, Loss: 0.721713
# Iteration: 4300, Loss: 0.716500
# Iteration: 4400, Loss: 0.900148
# Iteration: 4500, Loss: 0.740243
# Iteration: 4600, Loss: 0.748380
# Iteration: 4700, Loss: 0.710166
# Iteration: 4800, Loss: 0.652188
# Iteration: 4900, Loss: 0.712879
# Iteration: 5000, Loss: 0.712498
# Iteration: 5100, Loss: 0.795619
# Iteration: 5200, Loss: 0.638920
# Iteration: 5300, Loss: 0.536462
# Iteration: 5400, Loss: 0.723911
# Iteration: 5500, Loss: 0.702511
# Iteration: 5600, Loss: 0.728947
# Iteration: 5700, Loss: 0.669148
# Iteration: 5800, Loss: 0.732154
# Iteration: 5900, Loss: 0.571420
# Iteration: 6000, Loss: 0.682609
# Iteration: 6100, Loss: 0.715665
# Iteration: 6200, Loss: 0.654129
# Iteration: 6300, Loss: 0.734650
# Iteration: 6400, Loss: 0.698217
# Iteration: 6500, Loss: 0.730548
# Iteration: 6600, Loss: 0.771795
# Iteration: 6700, Loss: 0.634151
# Iteration: 6800, Loss: 0.577989
# Iteration: 6900, Loss: 0.775020
# Iteration: 7000, Loss: 0.800806
# Iteration: 7100, Loss: 0.647924
# Iteration: 7200, Loss: 0.721180
# Iteration: 7300, Loss: 0.621737
# Iteration: 7400, Loss: 0.774925
# Iteration: 7500, Loss: 0.629948
# Iteration: 7600, Loss: 0.656700
# Iteration: 7700, Loss: 0.589493
# Iteration: 7800, Loss: 0.650017
# Iteration: 7900, Loss: 0.580160
# Iteration: 8000, Loss: 0.695544
# Iteration: 8100, Loss: 0.595181
# Iteration: 8200, Loss: 0.637859
# Iteration: 8300, Loss: 0.657183
# Iteration: 8400, Loss: 0.724816
# Iteration: 8500, Loss: 0.652826
# Iteration: 8600, Loss: 0.567468
# Iteration: 8700, Loss: 0.596041
# Iteration: 8800, Loss: 0.568523
# Iteration: 8900, Loss: 0.599157
# Iteration: 9000, Loss: 0.570513
# Iteration: 9100, Loss: 0.446996
# Iteration: 9200, Loss: 0.600587
# Iteration: 9300, Loss: 0.655772
# Iteration: 9400, Loss: 0.698099
# Iteration: 9500, Loss: 0.511204
# Iteration: 9600, Loss: 0.528041
# Iteration: 9700, Loss: 0.561454
# Iteration: 9800, Loss: 0.556542
# Iteration: 9900, Loss: 0.619411
# Iteration: 10000, Loss: 0.691437
# Iteration: 10100, Loss: 0.715303
# Iteration: 10200, Loss: 0.634489
# Iteration: 10300, Loss: 0.541866
# Iteration: 10400, Loss: 0.654013
# Iteration: 10500, Loss: 0.531893
# Iteration: 10600, Loss: 0.641214
# Iteration: 10700, Loss: 0.576904
# Iteration: 10800, Loss: 0.548220
# Iteration: 10900, Loss: 0.559653
# Iteration: 11000, Loss: 0.500291
# Iteration: 11100, Loss: 0.461286
# Iteration: 11200, Loss: 0.539288
# Iteration: 11300, Loss: 0.602248
# Iteration: 11400, Loss: 0.506145
# Iteration: 11500, Loss: 0.509954
# Iteration: 11600, Loss: 0.466938
# Iteration: 11700, Loss: 0.522442
# Iteration: 11800, Loss: 0.566578
# Iteration: 11900, Loss: 0.605460
# Iteration: 12000, Loss: 0.515155
# Iteration: 12100, Loss: 0.508114
# Iteration: 12200, Loss: 0.500703
# Iteration: 12300, Loss: 0.528671
# Iteration: 12400, Loss: 0.483501
# Iteration: 12500, Loss: 0.598268
# Iteration: 12600, Loss: 0.423909
# Iteration: 12700, Loss: 0.522210
# Iteration: 12800, Loss: 0.527772
# Iteration: 12900, Loss: 0.482522
# Iteration: 13000, Loss: 0.549728
# Iteration: 13100, Loss: 0.556435
# Iteration: 13200, Loss: 0.499154
# Iteration: 13300, Loss: 0.472387
# Iteration: 13400, Loss: 0.539508
# Iteration: 13500, Loss: 0.522443
# Iteration: 13600, Loss: 0.519877
# Iteration: 13700, Loss: 0.526290
# Iteration: 13800, Loss: 0.557759
# Iteration: 13900, Loss: 0.541837
# Iteration: 14000, Loss: 0.565261
# Iteration: 14100, Loss: 0.567300
# Iteration: 14200, Loss: 0.470894
# Iteration: 14300, Loss: 0.555140
# Iteration: 14400, Loss: 0.546282
# Iteration: 14500, Loss: 0.473077
# Iteration: 14600, Loss: 0.498692
# Iteration: 14700, Loss: 0.607821
# Iteration: 14800, Loss: 0.610492
# Iteration: 14900, Loss: 0.470336
# Iteration: 15000, Loss: 0.442134
# Iteration: 15100, Loss: 0.587438
# Iteration: 15200, Loss: 0.591879
# Iteration: 15300, Loss: 0.531026
# Iteration: 15400, Loss: 0.541540
# Iteration: 15500, Loss: 0.532036
# Iteration: 15600, Loss: 0.470933
# Iteration: 15700, Loss: 0.463739
# Iteration: 15800, Loss: 0.682823
# Iteration: 15900, Loss: 0.545472
# Iteration: 16000, Loss: 0.596679
# Iteration: 16100, Loss: 0.513257
# Iteration: 16200, Loss: 0.460080
# Iteration: 16300, Loss: 0.437795
# Iteration: 16400, Loss: 0.734777
# Iteration: 16500, Loss: 0.570167
# Iteration: 16600, Loss: 0.505650
# Iteration: 16700, Loss: 0.472660
# Iteration: 16800, Loss: 0.577221
# Iteration: 16900, Loss: 0.436590
# Iteration: 17000, Loss: 0.518168
# Iteration: 17100, Loss: 0.545111
# Iteration: 17200, Loss: 0.484853
# Iteration: 17300, Loss: 0.449907
# Iteration: 17400, Loss: 0.567232
# Iteration: 17500, Loss: 0.580715
# Iteration: 17600, Loss: 0.579016
# Iteration: 17700, Loss: 0.460521
# Iteration: 17800, Loss: 0.505405
# Iteration: 17900, Loss: 0.492535
# Iteration: 18000, Loss: 0.480130
# Iteration: 18100, Loss: 0.521065
# Iteration: 18200, Loss: 0.410430
# Iteration: 18300, Loss: 0.490533
# Iteration: 18400, Loss: 0.530418
# Iteration: 18500, Loss: 0.583724
# Iteration: 18600, Loss: 0.509187
# Iteration: 18700, Loss: 0.499808
# Iteration: 18800, Loss: 0.584460
# Iteration: 18900, Loss: 0.421503
# Iteration: 19000, Loss: 0.525017
# Iteration: 19100, Loss: 0.497012
# Iteration: 19200, Loss: 0.500804
# Iteration: 19300, Loss: 0.478872
# Iteration: 19400, Loss: 0.582035
# Iteration: 19500, Loss: 0.488841
# Iteration: 19600, Loss: 0.443994
# Iteration: 19700, Loss: 0.528489
# Iteration: 19800, Loss: 0.441167
# Iteration: 19900, Loss: 0.533252
# Iteration: 20000, Loss: 0.435503

# %%
# Given Result
# Out:
# Iteration: 100, Loss: 2.769716
# Iteration: 200, Loss: 1.574507
# Iteration: 300, Loss: 1.403120
# Iteration: 400, Loss: 1.442013
# Iteration: 500, Loss: 1.377953
# Iteration: 600, Loss: 1.428441
# Iteration: 700, Loss: 1.447513
# Iteration: 800, Loss: 1.440054
# Iteration: 900, Loss: 1.123454
# Iteration: 1000, Loss: 1.098575
# Iteration: 1100, Loss: 1.078805
# Iteration: 1200, Loss: 1.115782
# Iteration: 1300, Loss: 1.264505
# Iteration: 1400, Loss: 1.003935
# Iteration: 1500, Loss: 0.940511
# Iteration: 1600, Loss: 1.132631
# Iteration: 1700, Loss: 1.025079
# Iteration: 1800, Loss: 1.120098
# Iteration: 1900, Loss: 0.887357
# Iteration: 2000, Loss: 1.112836
# Iteration: 2100, Loss: 0.960112
# Iteration: 2200, Loss: 1.073669
# Iteration: 2300, Loss: 1.032493
# Iteration: 2400, Loss: 0.946448
# Iteration: 2500, Loss: 0.883482
# Iteration: 2600, Loss: 0.856605
# Iteration: 2700, Loss: 1.064430
# Iteration: 2800, Loss: 0.799079
# Iteration: 2900, Loss: 0.969057
# Iteration: 3000, Loss: 0.774104
# Iteration: 3100, Loss: 0.785062
# Iteration: 3200, Loss: 0.828452
# Iteration: 3300, Loss: 0.834865
# Iteration: 3400, Loss: 0.896579
# Iteration: 3500, Loss: 0.839193
# Iteration: 3600, Loss: 0.898088
# Iteration: 3700, Loss: 0.698576
# Iteration: 3800, Loss: 0.829471
# Iteration: 3900, Loss: 0.730356
# Iteration: 4000, Loss: 0.749297
# Iteration: 4100, Loss: 0.796198
# Iteration: 4200, Loss: 0.737861
# Iteration: 4300, Loss: 0.700059
# Iteration: 4400, Loss: 0.863546
# Iteration: 4500, Loss: 0.800743
# Iteration: 4600, Loss: 0.813580
# Iteration: 4700, Loss: 0.658328
# Iteration: 4800, Loss: 0.868068
# Iteration: 4900, Loss: 0.708953
# Iteration: 5000, Loss: 0.696934
# Iteration: 5100, Loss: 0.633173
# Iteration: 5200, Loss: 0.773097
# Iteration: 5300, Loss: 0.709829
# Iteration: 5400, Loss: 0.776796
# Iteration: 5500, Loss: 0.740059
# Iteration: 5600, Loss: 0.599925
# Iteration: 5700, Loss: 0.681939
# Iteration: 5800, Loss: 0.707702
# Iteration: 5900, Loss: 0.690066
# Iteration: 6000, Loss: 0.809559
# Iteration: 6100, Loss: 0.678773
# Iteration: 6200, Loss: 0.649790
# Iteration: 6300, Loss: 0.779276
# Iteration: 6400, Loss: 0.774077
# Iteration: 6500, Loss: 0.678883
# Iteration: 6600, Loss: 0.748829
# Iteration: 6700, Loss: 0.728359
# Iteration: 6800, Loss: 0.712358
# Iteration: 6900, Loss: 0.711150
# Iteration: 7000, Loss: 0.735689
# Iteration: 7100, Loss: 0.607649
# Iteration: 7200, Loss: 0.722437
# Iteration: 7300, Loss: 0.585572
# Iteration: 7400, Loss: 0.643255
# Iteration: 7500, Loss: 0.654195
# Iteration: 7600, Loss: 0.640945
# Iteration: 7700, Loss: 0.622632
# Iteration: 7800, Loss: 0.546032
# Iteration: 7900, Loss: 0.670141
# Iteration: 8000, Loss: 0.536121
# Iteration: 8100, Loss: 0.582330
# Iteration: 8200, Loss: 0.573661
# Iteration: 8300, Loss: 0.651232
# Iteration: 8400, Loss: 0.598501
# Iteration: 8500, Loss: 0.544196
# Iteration: 8600, Loss: 0.575550
# Iteration: 8700, Loss: 0.568649
# Iteration: 8800, Loss: 0.560198
# Iteration: 8900, Loss: 0.664636
# Iteration: 9000, Loss: 0.618282
# Iteration: 9100, Loss: 0.536497
# Iteration: 9200, Loss: 0.597298
# Iteration: 9300, Loss: 0.617966
# Iteration: 9400, Loss: 0.651513
# Iteration: 9500, Loss: 0.571514
# Iteration: 9600, Loss: 0.642046
# Iteration: 9700, Loss: 0.600645
# Iteration: 9800, Loss: 0.675982
# Iteration: 9900, Loss: 0.595083
# Iteration: 10000, Loss: 0.479329
# Iteration: 10100, Loss: 0.568267
# Iteration: 10200, Loss: 0.610005
# Iteration: 10300, Loss: 0.513185
# Iteration: 10400, Loss: 0.575455
# Iteration: 10500, Loss: 0.597266
# Iteration: 10600, Loss: 0.568870
# Iteration: 10700, Loss: 0.540819
# Iteration: 10800, Loss: 0.510774
# Iteration: 10900, Loss: 0.539605
# Iteration: 11000, Loss: 0.490516
# Iteration: 11100, Loss: 0.602884
# Iteration: 11200, Loss: 0.616868
# Iteration: 11300, Loss: 0.605189
# Iteration: 11400, Loss: 0.593325
# Iteration: 11500, Loss: 0.564609
# Iteration: 11600, Loss: 0.582791
# Iteration: 11700, Loss: 0.550812
# Iteration: 11800, Loss: 0.559391
# Iteration: 11900, Loss: 0.506753
# Iteration: 12000, Loss: 0.584626
# Iteration: 12100, Loss: 0.509472
# Iteration: 12200, Loss: 0.455885
# Iteration: 12300, Loss: 0.603062
# Iteration: 12400, Loss: 0.637693
# Iteration: 12500, Loss: 0.508612
# Iteration: 12600, Loss: 0.528264
# Iteration: 12700, Loss: 0.557422
# Iteration: 12800, Loss: 0.535200
# Iteration: 12900, Loss: 0.493145
# Iteration: 13000, Loss: 0.614268
# Iteration: 13100, Loss: 0.599480
# Iteration: 13200, Loss: 0.627034
# Iteration: 13300, Loss: 0.532652
# Iteration: 13400, Loss: 0.531870
# Iteration: 13500, Loss: 0.536636
# Iteration: 13600, Loss: 0.500799
# Iteration: 13700, Loss: 0.464711
# Iteration: 13800, Loss: 0.473607
# Iteration: 13900, Loss: 0.484782
# Iteration: 14000, Loss: 0.566043
# Iteration: 14100, Loss: 0.541477
# Iteration: 14200, Loss: 0.501090
# Iteration: 14300, Loss: 0.508751
# Iteration: 14400, Loss: 0.565854
# Iteration: 14500, Loss: 0.515350
# Iteration: 14600, Loss: 0.441883
# Iteration: 14700, Loss: 0.555699
# Iteration: 14800, Loss: 0.535993
# Iteration: 14900, Loss: 0.537928
# Iteration: 15000, Loss: 0.478711
# Iteration: 15100, Loss: 0.506860
# Iteration: 15200, Loss: 0.564170
# Iteration: 15300, Loss: 0.501251
# Iteration: 15400, Loss: 0.510655
# Iteration: 15500, Loss: 0.534498
# Iteration: 15600, Loss: 0.531664
# Iteration: 15700, Loss: 0.512566
# Iteration: 15800, Loss: 0.465423
# Iteration: 15900, Loss: 0.518297
# Iteration: 16000, Loss: 0.464090
# Iteration: 16100, Loss: 0.499326
# Iteration: 16200, Loss: 0.480812
# Iteration: 16300, Loss: 0.527127
# Iteration: 16400, Loss: 0.504507
# Iteration: 16500, Loss: 0.482814
# Iteration: 16600, Loss: 0.491768
# Iteration: 16700, Loss: 0.576775
# Iteration: 16800, Loss: 0.505052
# Iteration: 16900, Loss: 0.524122
# Iteration: 17000, Loss: 0.550437
# Iteration: 17100, Loss: 0.505921
# Iteration: 17200, Loss: 0.513350
# Iteration: 17300, Loss: 0.443921
# Iteration: 17400, Loss: 0.449299
# Iteration: 17500, Loss: 0.524285
# Iteration: 17600, Loss: 0.378820
# Iteration: 17700, Loss: 0.546154
# Iteration: 17800, Loss: 0.557975
# Iteration: 17900, Loss: 0.620080
# Iteration: 18000, Loss: 0.564723
# Iteration: 18100, Loss: 0.451166
# Iteration: 18200, Loss: 0.485477
# Iteration: 18300, Loss: 0.462077
# Iteration: 18400, Loss: 0.541489
# Iteration: 18500, Loss: 0.476764
# Iteration: 18600, Loss: 0.453127
# Iteration: 18700, Loss: 0.492060
# Iteration: 18800, Loss: 0.549232
# Iteration: 18900, Loss: 0.508694
# Iteration: 19000, Loss: 0.474160
# Iteration: 19100, Loss: 0.480057
# Iteration: 19200, Loss: 0.497857
# Iteration: 19300, Loss: 0.501872
# Iteration: 19400, Loss: 0.530759
# Iteration: 19500, Loss: 0.432883
# Iteration: 19600, Loss: 0.463135
# Iteration: 19700, Loss: 0.478814
# Iteration: 19800, Loss: 0.475781
# Iteration: 19900, Loss: 0.466110
# Iteration: 20000, Loss: 0.498858
# Iteration: 20100, Loss: 0.488224
# Iteration: 20200, Loss: 0.467925
# Iteration: 20300, Loss: 0.477793
# Iteration: 20400, Loss: 0.495204
# Iteration: 20500, Loss: 0.466821
# Iteration: 20600, Loss: 0.467883
# Iteration: 20700, Loss: 0.414899
# Iteration: 20800, Loss: 0.438898
# Iteration: 20900, Loss: 0.507594
# Iteration: 21000, Loss: 0.418054
# Iteration: 21100, Loss: 0.481124
# Iteration: 21200, Loss: 0.460511
# Iteration: 21300, Loss: 0.420194
# Iteration: 21400, Loss: 0.425079
# Iteration: 21500, Loss: 0.416273
# Iteration: 21600, Loss: 0.348699
# Iteration: 21700, Loss: 0.394937
# Iteration: 21800, Loss: 0.473193
# Iteration: 21900, Loss: 0.465289
# Iteration: 22000, Loss: 0.438223
# Iteration: 22100, Loss: 0.463666
# Iteration: 22200, Loss: 0.441545
# Iteration: 22300, Loss: 0.521143
# Iteration: 22400, Loss: 0.438275
# Iteration: 22500, Loss: 0.465825
# Iteration: 22600, Loss: 0.415447
# Iteration: 22700, Loss: 0.384117
# Iteration: 22800, Loss: 0.404211
# Iteration: 22900, Loss: 0.481211
# Iteration: 23000, Loss: 0.347526
# Iteration: 23100, Loss: 0.389690
# Iteration: 23200, Loss: 0.498645
# Iteration: 23300, Loss: 0.429570
# Iteration: 23400, Loss: 0.478570
# Iteration: 23500, Loss: 0.407261
# Iteration: 23600, Loss: 0.463680
# Iteration: 23700, Loss: 0.367052
# Iteration: 23800, Loss: 0.452883
# Iteration: 23900, Loss: 0.462600
# Iteration: 24000, Loss: 0.377649
# Iteration: 24100, Loss: 0.414143
# Iteration: 24200, Loss: 0.453858
# Iteration: 24300, Loss: 0.436042
# Iteration: 24400, Loss: 0.417915
# Iteration: 24500, Loss: 0.524581
# Iteration: 24600, Loss: 0.439463
# Iteration: 24700, Loss: 0.438927
# Iteration: 24800, Loss: 0.514587
# Iteration: 24900, Loss: 0.420921
# Iteration: 25000, Loss: 0.439076
# Iteration: 25100, Loss: 0.458869
# Iteration: 25200, Loss: 0.432853
# Iteration: 25300, Loss: 0.376986
# Iteration: 25400, Loss: 0.477790
# Iteration: 25500, Loss: 0.488104
# Iteration: 25600, Loss: 0.420671
# Iteration: 25700, Loss: 0.426297
# Iteration: 25800, Loss: 0.458830
# Iteration: 25900, Loss: 0.477280
# Iteration: 26000, Loss: 0.418207
# Iteration: 26100, Loss: 0.448335
# Iteration: 26200, Loss: 0.375065
# Iteration: 26300, Loss: 0.492327
# Iteration: 26400, Loss: 0.448720
# Iteration: 26500, Loss: 0.444777
# Iteration: 26600, Loss: 0.479643
# Iteration: 26700, Loss: 0.508187
# Iteration: 26800, Loss: 0.431873
# Iteration: 26900, Loss: 0.422252
# Iteration: 27000, Loss: 0.393428
# Iteration: 27100, Loss: 0.418974
# Iteration: 27200, Loss: 0.387654
# Iteration: 27300, Loss: 0.447386
# Iteration: 27400, Loss: 0.417841
# Iteration: 27500, Loss: 0.439660
# Iteration: 27600, Loss: 0.469917
# Iteration: 27700, Loss: 0.391861
# Iteration: 27800, Loss: 0.449818
# Iteration: 27900, Loss: 0.363510
# Iteration: 28000, Loss: 0.434464
# Iteration: 28100, Loss: 0.388605
# Iteration: 28200, Loss: 0.475534
# Iteration: 28300, Loss: 0.478094
# Iteration: 28400, Loss: 0.451943
# Iteration: 28500, Loss: 0.480034
# Iteration: 28600, Loss: 0.428855
# Iteration: 28700, Loss: 0.461188
# Iteration: 28800, Loss: 0.428115
# Iteration: 28900, Loss: 0.520781
# Iteration: 29000, Loss: 0.410722
# Iteration: 29100, Loss: 0.458460
# Iteration: 29200, Loss: 0.474475
# Iteration: 29300, Loss: 0.512766
# Iteration: 29400, Loss: 0.361588
# Iteration: 29500, Loss: 0.404643
# Iteration: 29600, Loss: 0.439924
# Iteration: 29700, Loss: 0.531730
# Iteration: 29800, Loss: 0.486879
# Iteration: 29900, Loss: 0.407743
# Iteration: 30000, Loss: 0.435751

# %% [markdown]
# ### 2.3 Discuss the result [3 points]
# - Compare and Discuss the results. Note that it must contain the quantitative and qualitative results.
# - Use the below 'validation_miou' function to evaluate your model. Your model should perform better than the example model **(0.47 mIoU)**.
# - Use the above 'decode_label' function to visualize the network output.

# %%
def validation_miou(model):
    max_label = 20
    hist = np.zeros((max_label + 1, max_label + 1))
    
    def fast_hist(a, b, n):
        k = (a >= 0) & (a < n)
        return np.bincount(n * a[k].astype(int) + b[k], minlength=n ** 2).reshape(n, n)
    
    val_list = open('/root/dataset-dllab/lab06/list/val.txt').readlines()
    
    with torch.no_grad():
        for idx, i in enumerate(val_list):
            print('{}/{} ...'.format(idx + 1, len(val_list)))

            img = cv2.imread(os.path.join('/root/dataset-dllab/lab06/img', i[:-1] + '.jpg')).astype(float)

            img[:, :, 0] -= 104.008
            img[:, :, 1] -= 116.669
            img[:, :, 2] -= 122.675

            data = torch.from_numpy(img.transpose((2,0,1))).float().cuda().unsqueeze(0)

            score = model(data)

            output = score.cpu().data[0].numpy().transpose(1, 2, 0)
            output = np.argmax(output, axis=2)
            gt = cv2.imread(os.path.join('/root/dataset-dllab/lab06/gt', i[:-1] + '.png'), 0)

            hist += fast_hist(gt.flatten(), output.flatten(), max_label + 1)

        miou = np.diag(hist) / (hist.sum(1) + hist.sum(0) - np.diag(hist))
        print("Mean iou = ", np.sum(miou) / len(miou))
        
    return np.sum(miou) / len(miou)

# %%
#############
# CODE HERE #
############# 
# load model with minimum loss
model_data = torch.load("/root/pretrain/weights/lab06/fcn.pkl")
model.load_state_dict(model_data["state_dict"])

#mIoU of model
model.eval()
fcn8s_miou= validation_miou(model)

#mIoU of model in section 1.2.2
bilinearVgg_miou= validation_miou(conv_vgg_upsample)
# Out:
# 1/1449 ...
# 2/1449 ...
# 3/1449 ...
# 4/1449 ...
# 5/1449 ...
# 6/1449 ...
# 7/1449 ...
# 8/1449 ...
# 9/1449 ...
# 10/1449 ...
# 11/1449 ...
# 12/1449 ...
# 13/1449 ...
# 14/1449 ...
# 15/1449 ...
# 16/1449 ...
# 17/1449 ...
# 18/1449 ...
# 19/1449 ...
# 20/1449 ...
# 21/1449 ...
# 22/1449 ...
# 23/1449 ...
# 24/1449 ...
# 25/1449 ...
# 26/1449 ...
# 27/1449 ...
# 28/1449 ...
# 29/1449 ...
# 30/1449 ...
# 31/1449 ...
# 32/1449 ...
# 33/1449 ...
# 34/1449 ...
# 35/1449 ...
# 36/1449 ...
# 37/1449 ...
# 38/1449 ...
# 39/1449 ...
# 40/1449 ...
# 41/1449 ...
# 42/1449 ...
# 43/1449 ...
# 44/1449 ...
# 45/1449 ...
# 46/1449 ...
# 47/1449 ...
# 48/1449 ...
# 49/1449 ...
# 50/1449 ...
# 51/1449 ...
# 52/1449 ...
# 53/1449 ...
# 54/1449 ...
# 55/1449 ...
# 56/1449 ...
# 57/1449 ...
# 58/1449 ...
# 59/1449 ...
# 60/1449 ...
# 61/1449 ...
# 62/1449 ...
# 63/1449 ...
# 64/1449 ...
# 65/1449 ...
# 66/1449 ...
# 67/1449 ...
# 68/1449 ...
# 69/1449 ...
# 70/1449 ...
# 71/1449 ...
# 72/1449 ...
# 73/1449 ...
# 74/1449 ...
# 75/1449 ...
# 76/1449 ...
# 77/1449 ...
# 78/1449 ...
# 79/1449 ...
# 80/1449 ...
# 81/1449 ...
# 82/1449 ...
# 83/1449 ...
# 84/1449 ...
# 85/1449 ...
# 86/1449 ...
# 87/1449 ...
# 88/1449 ...
# 89/1449 ...
# 90/1449 ...
# 91/1449 ...
# 92/1449 ...
# 93/1449 ...
# 94/1449 ...
# 95/1449 ...
# 96/1449 ...
# 97/1449 ...
# 98/1449 ...
# 99/1449 ...
# 100/1449 ...
# 101/1449 ...
# 102/1449 ...
# 103/1449 ...
# 104/1449 ...
# 105/1449 ...
# 106/1449 ...
# 107/1449 ...
# 108/1449 ...
# 109/1449 ...
# 110/1449 ...
# 111/1449 ...
# 112/1449 ...
# 113/1449 ...
# 114/1449 ...
# 115/1449 ...
# 116/1449 ...
# 117/1449 ...
# 118/1449 ...
# 119/1449 ...
# 120/1449 ...
# 121/1449 ...
# 122/1449 ...
# 123/1449 ...
# 124/1449 ...
# 125/1449 ...
# 126/1449 ...
# 127/1449 ...
# 128/1449 ...
# 129/1449 ...
# 130/1449 ...
# 131/1449 ...
# 132/1449 ...
# 133/1449 ...
# 134/1449 ...
# 135/1449 ...
# 136/1449 ...
# 137/1449 ...
# 138/1449 ...
# 139/1449 ...
# 140/1449 ...
# 141/1449 ...
# 142/1449 ...
# 143/1449 ...
# 144/1449 ...
# 145/1449 ...
# 146/1449 ...
# 147/1449 ...
# 148/1449 ...
# 149/1449 ...
# 150/1449 ...
# 151/1449 ...
# 152/1449 ...
# 153/1449 ...
# 154/1449 ...
# 155/1449 ...
# 156/1449 ...
# 157/1449 ...
# 158/1449 ...
# 159/1449 ...
# 160/1449 ...
# 161/1449 ...
# 162/1449 ...
# 163/1449 ...
# 164/1449 ...
# 165/1449 ...
# 166/1449 ...
# 167/1449 ...
# 168/1449 ...
# 169/1449 ...
# 170/1449 ...
# 171/1449 ...
# 172/1449 ...
# 173/1449 ...
# 174/1449 ...
# 175/1449 ...
# 176/1449 ...
# 177/1449 ...
# 178/1449 ...
# 179/1449 ...
# 180/1449 ...
# 181/1449 ...
# 182/1449 ...
# 183/1449 ...
# 184/1449 ...
# 185/1449 ...
# 186/1449 ...
# 187/1449 ...
# 188/1449 ...
# 189/1449 ...
# 190/1449 ...
# 191/1449 ...
# 192/1449 ...
# 193/1449 ...
# 194/1449 ...
# 195/1449 ...
# 196/1449 ...
# 197/1449 ...
# 198/1449 ...
# 199/1449 ...
# 200/1449 ...
# 201/1449 ...
# 202/1449 ...
# 203/1449 ...
# 204/1449 ...
# 205/1449 ...
# 206/1449 ...
# 207/1449 ...
# 208/1449 ...
# 209/1449 ...
# 210/1449 ...
# 211/1449 ...
# 212/1449 ...
# 213/1449 ...
# 214/1449 ...
# 215/1449 ...
# 216/1449 ...
# 217/1449 ...
# 218/1449 ...
# 219/1449 ...
# 220/1449 ...
# 221/1449 ...
# 222/1449 ...
# 223/1449 ...
# 224/1449 ...
# 225/1449 ...
# 226/1449 ...
# 227/1449 ...
# 228/1449 ...
# 229/1449 ...
# 230/1449 ...
# 231/1449 ...
# 232/1449 ...
# 233/1449 ...
# 234/1449 ...
# 235/1449 ...
# 236/1449 ...
# 237/1449 ...
# 238/1449 ...
# 239/1449 ...
# 240/1449 ...
# 241/1449 ...
# 242/1449 ...
# 243/1449 ...
# 244/1449 ...
# 245/1449 ...
# 246/1449 ...
# 247/1449 ...
# 248/1449 ...
# 249/1449 ...
# 250/1449 ...
# 251/1449 ...
# 252/1449 ...
# 253/1449 ...
# 254/1449 ...
# 255/1449 ...
# 256/1449 ...
# 257/1449 ...
# 258/1449 ...
# 259/1449 ...
# 260/1449 ...
# 261/1449 ...
# 262/1449 ...
# 263/1449 ...
# 264/1449 ...
# 265/1449 ...
# 266/1449 ...
# 267/1449 ...
# 268/1449 ...
# 269/1449 ...
# 270/1449 ...
# 271/1449 ...
# 272/1449 ...
# 273/1449 ...
# 274/1449 ...
# 275/1449 ...
# 276/1449 ...
# 277/1449 ...
# 278/1449 ...
# 279/1449 ...
# 280/1449 ...
# 281/1449 ...
# 282/1449 ...
# 283/1449 ...
# 284/1449 ...
# 285/1449 ...
# 286/1449 ...
# 287/1449 ...
# 288/1449 ...
# 289/1449 ...
# 290/1449 ...
# 291/1449 ...
# 292/1449 ...
# 293/1449 ...
# 294/1449 ...
# 295/1449 ...
# 296/1449 ...
# 297/1449 ...
# 298/1449 ...
# 299/1449 ...
# 300/1449 ...
# 301/1449 ...
# 302/1449 ...
# 303/1449 ...
# 304/1449 ...
# 305/1449 ...
# 306/1449 ...
# 307/1449 ...
# 308/1449 ...
# 309/1449 ...
# 310/1449 ...
# 311/1449 ...
# 312/1449 ...
# 313/1449 ...
# 314/1449 ...
# 315/1449 ...
# 316/1449 ...
# 317/1449 ...
# 318/1449 ...
# 319/1449 ...
# 320/1449 ...
# 321/1449 ...
# 322/1449 ...
# 323/1449 ...
# 324/1449 ...
# 325/1449 ...
# 326/1449 ...
# 327/1449 ...
# 328/1449 ...
# 329/1449 ...
# 330/1449 ...
# 331/1449 ...
# 332/1449 ...
# 333/1449 ...
# 334/1449 ...
# 335/1449 ...
# 336/1449 ...
# 337/1449 ...
# 338/1449 ...
# 339/1449 ...
# 340/1449 ...
# 341/1449 ...
# 342/1449 ...
# 343/1449 ...
# 344/1449 ...
# 345/1449 ...
# 346/1449 ...
# 347/1449 ...
# 348/1449 ...
# 349/1449 ...
# 350/1449 ...
# 351/1449 ...
# 352/1449 ...
# 353/1449 ...
# 354/1449 ...
# 355/1449 ...
# 356/1449 ...
# 357/1449 ...
# 358/1449 ...
# 359/1449 ...
# 360/1449 ...
# 361/1449 ...
# 362/1449 ...
# 363/1449 ...
# 364/1449 ...
# 365/1449 ...
# 366/1449 ...
# 367/1449 ...
# 368/1449 ...
# 369/1449 ...
# 370/1449 ...
# 371/1449 ...
# 372/1449 ...
# 373/1449 ...
# 374/1449 ...
# 375/1449 ...
# 376/1449 ...
# 377/1449 ...
# 378/1449 ...
# 379/1449 ...
# 380/1449 ...
# 381/1449 ...
# 382/1449 ...
# 383/1449 ...
# 384/1449 ...
# 385/1449 ...
# 386/1449 ...
# 387/1449 ...
# 388/1449 ...
# 389/1449 ...
# 390/1449 ...
# 391/1449 ...
# 392/1449 ...
# 393/1449 ...
# 394/1449 ...
# 395/1449 ...
# 396/1449 ...
# 397/1449 ...
# 398/1449 ...
# 399/1449 ...
# 400/1449 ...
# 401/1449 ...
# 402/1449 ...
# 403/1449 ...
# 404/1449 ...
# 405/1449 ...
# 406/1449 ...
# 407/1449 ...
# 408/1449 ...
# 409/1449 ...
# 410/1449 ...
# 411/1449 ...
# 412/1449 ...
# 413/1449 ...
# 414/1449 ...
# 415/1449 ...
# 416/1449 ...
# 417/1449 ...
# 418/1449 ...
# 419/1449 ...
# 420/1449 ...
# 421/1449 ...
# 422/1449 ...
# 423/1449 ...
# 424/1449 ...
# 425/1449 ...
# 426/1449 ...
# 427/1449 ...
# 428/1449 ...
# 429/1449 ...
# 430/1449 ...
# 431/1449 ...
# 432/1449 ...
# 433/1449 ...
# 434/1449 ...
# 435/1449 ...
# 436/1449 ...
# 437/1449 ...
# 438/1449 ...
# 439/1449 ...
# 440/1449 ...
# 441/1449 ...
# 442/1449 ...
# 443/1449 ...
# 444/1449 ...
# 445/1449 ...
# 446/1449 ...
# 447/1449 ...
# 448/1449 ...
# 449/1449 ...
# 450/1449 ...
# 451/1449 ...
# 452/1449 ...
# 453/1449 ...
# 454/1449 ...
# 455/1449 ...
# 456/1449 ...
# 457/1449 ...
# 458/1449 ...
# 459/1449 ...
# 460/1449 ...
# 461/1449 ...
# 462/1449 ...
# 463/1449 ...
# 464/1449 ...
# 465/1449 ...
# 466/1449 ...
# 467/1449 ...
# 468/1449 ...
# 469/1449 ...
# 470/1449 ...
# 471/1449 ...
# 472/1449 ...
# 473/1449 ...
# 474/1449 ...
# 475/1449 ...
# 476/1449 ...
# 477/1449 ...
# 478/1449 ...
# 479/1449 ...
# 480/1449 ...
# 481/1449 ...
# 482/1449 ...
# 483/1449 ...
# 484/1449 ...
# 485/1449 ...
# 486/1449 ...
# 487/1449 ...
# 488/1449 ...
# 489/1449 ...
# 490/1449 ...
# 491/1449 ...
# 492/1449 ...
# 493/1449 ...
# 494/1449 ...
# 495/1449 ...
# 496/1449 ...
# 497/1449 ...
# 498/1449 ...
# 499/1449 ...
# 500/1449 ...
# 501/1449 ...
# 502/1449 ...
# 503/1449 ...
# 504/1449 ...
# 505/1449 ...
# 506/1449 ...
# 507/1449 ...
# 508/1449 ...
# 509/1449 ...
# 510/1449 ...
# 511/1449 ...
# 512/1449 ...
# 513/1449 ...
# 514/1449 ...
# 515/1449 ...
# 516/1449 ...
# 517/1449 ...
# 518/1449 ...
# 519/1449 ...
# 520/1449 ...
# 521/1449 ...
# 522/1449 ...
# 523/1449 ...
# 524/1449 ...
# 525/1449 ...
# 526/1449 ...
# 527/1449 ...
# 528/1449 ...
# 529/1449 ...
# 530/1449 ...
# 531/1449 ...
# 532/1449 ...
# 533/1449 ...
# 534/1449 ...
# 535/1449 ...
# 536/1449 ...
# 537/1449 ...
# 538/1449 ...
# 539/1449 ...
# 540/1449 ...
# 541/1449 ...
# 542/1449 ...
# 543/1449 ...
# 544/1449 ...
# 545/1449 ...
# 546/1449 ...
# 547/1449 ...
# 548/1449 ...
# 549/1449 ...
# 550/1449 ...
# 551/1449 ...
# 552/1449 ...
# 553/1449 ...
# 554/1449 ...
# 555/1449 ...
# 556/1449 ...
# 557/1449 ...
# 558/1449 ...
# 559/1449 ...
# 560/1449 ...
# 561/1449 ...
# 562/1449 ...
# 563/1449 ...
# 564/1449 ...
# 565/1449 ...
# 566/1449 ...
# 567/1449 ...
# 568/1449 ...
# 569/1449 ...
# 570/1449 ...
# 571/1449 ...
# 572/1449 ...
# 573/1449 ...
# 574/1449 ...
# 575/1449 ...
# 576/1449 ...
# 577/1449 ...
# 578/1449 ...
# 579/1449 ...
# 580/1449 ...
# 581/1449 ...
# 582/1449 ...
# 583/1449 ...
# 584/1449 ...
# 585/1449 ...
# 586/1449 ...
# 587/1449 ...
# 588/1449 ...
# 589/1449 ...
# 590/1449 ...
# 591/1449 ...
# 592/1449 ...
# 593/1449 ...
# 594/1449 ...
# 595/1449 ...
# 596/1449 ...
# 597/1449 ...
# 598/1449 ...
# 599/1449 ...
# 600/1449 ...
# 601/1449 ...
# 602/1449 ...
# 603/1449 ...
# 604/1449 ...
# 605/1449 ...
# 606/1449 ...
# 607/1449 ...
# 608/1449 ...
# 609/1449 ...
# 610/1449 ...
# 611/1449 ...
# 612/1449 ...
# 613/1449 ...
# 614/1449 ...
# 615/1449 ...
# 616/1449 ...
# 617/1449 ...
# 618/1449 ...
# 619/1449 ...
# 620/1449 ...
# 621/1449 ...
# 622/1449 ...
# 623/1449 ...
# 624/1449 ...
# 625/1449 ...
# 626/1449 ...
# 627/1449 ...
# 628/1449 ...
# 629/1449 ...
# 630/1449 ...
# 631/1449 ...
# 632/1449 ...
# 633/1449 ...
# 634/1449 ...
# 635/1449 ...
# 636/1449 ...
# 637/1449 ...
# 638/1449 ...
# 639/1449 ...
# 640/1449 ...
# 641/1449 ...
# 642/1449 ...
# 643/1449 ...
# 644/1449 ...
# 645/1449 ...
# 646/1449 ...
# 647/1449 ...
# 648/1449 ...
# 649/1449 ...
# 650/1449 ...
# 651/1449 ...
# 652/1449 ...
# 653/1449 ...
# 654/1449 ...
# 655/1449 ...
# 656/1449 ...
# 657/1449 ...
# 658/1449 ...
# 659/1449 ...
# 660/1449 ...
# 661/1449 ...
# 662/1449 ...
# 663/1449 ...
# 664/1449 ...
# 665/1449 ...
# 666/1449 ...
# 667/1449 ...
# 668/1449 ...
# 669/1449 ...
# 670/1449 ...
# 671/1449 ...
# 672/1449 ...
# 673/1449 ...
# 674/1449 ...
# 675/1449 ...
# 676/1449 ...
# 677/1449 ...
# 678/1449 ...
# 679/1449 ...
# 680/1449 ...
# 681/1449 ...
# 682/1449 ...
# 683/1449 ...
# 684/1449 ...
# 685/1449 ...
# 686/1449 ...
# 687/1449 ...
# 688/1449 ...
# 689/1449 ...
# 690/1449 ...
# 691/1449 ...
# 692/1449 ...
# 693/1449 ...
# 694/1449 ...
# 695/1449 ...
# 696/1449 ...
# 697/1449 ...
# 698/1449 ...
# 699/1449 ...
# 700/1449 ...
# 701/1449 ...
# 702/1449 ...
# 703/1449 ...
# 704/1449 ...
# 705/1449 ...
# 706/1449 ...
# 707/1449 ...
# 708/1449 ...
# 709/1449 ...
# 710/1449 ...
# 711/1449 ...
# 712/1449 ...
# 713/1449 ...
# 714/1449 ...
# 715/1449 ...
# 716/1449 ...
# 717/1449 ...
# 718/1449 ...
# 719/1449 ...
# 720/1449 ...
# 721/1449 ...
# 722/1449 ...
# 723/1449 ...
# 724/1449 ...
# 725/1449 ...
# 726/1449 ...
# 727/1449 ...
# 728/1449 ...
# 729/1449 ...
# 730/1449 ...
# 731/1449 ...
# 732/1449 ...
# 733/1449 ...
# 734/1449 ...
# 735/1449 ...
# 736/1449 ...
# 737/1449 ...
# 738/1449 ...
# 739/1449 ...
# 740/1449 ...
# 741/1449 ...
# 742/1449 ...
# 743/1449 ...
# 744/1449 ...
# 745/1449 ...
# 746/1449 ...
# 747/1449 ...
# 748/1449 ...
# 749/1449 ...
# 750/1449 ...
# 751/1449 ...
# 752/1449 ...
# 753/1449 ...
# 754/1449 ...
# 755/1449 ...
# 756/1449 ...
# 757/1449 ...
# 758/1449 ...
# 759/1449 ...
# 760/1449 ...
# 761/1449 ...
# 762/1449 ...
# 763/1449 ...
# 764/1449 ...
# 765/1449 ...
# 766/1449 ...
# 767/1449 ...
# 768/1449 ...
# 769/1449 ...
# 770/1449 ...
# 771/1449 ...
# 772/1449 ...
# 773/1449 ...
# 774/1449 ...
# 775/1449 ...
# 776/1449 ...
# 777/1449 ...
# 778/1449 ...
# 779/1449 ...
# 780/1449 ...
# 781/1449 ...
# 782/1449 ...
# 783/1449 ...
# 784/1449 ...
# 785/1449 ...
# 786/1449 ...
# 787/1449 ...
# 788/1449 ...
# 789/1449 ...
# 790/1449 ...
# 791/1449 ...
# 792/1449 ...
# 793/1449 ...
# 794/1449 ...
# 795/1449 ...
# 796/1449 ...
# 797/1449 ...
# 798/1449 ...
# 799/1449 ...
# 800/1449 ...
# 801/1449 ...
# 802/1449 ...
# 803/1449 ...
# 804/1449 ...
# 805/1449 ...
# 806/1449 ...
# 807/1449 ...
# 808/1449 ...
# 809/1449 ...
# 810/1449 ...
# 811/1449 ...
# 812/1449 ...
# 813/1449 ...
# 814/1449 ...
# 815/1449 ...
# 816/1449 ...
# 817/1449 ...
# 818/1449 ...
# 819/1449 ...
# 820/1449 ...
# 821/1449 ...
# 822/1449 ...
# 823/1449 ...
# 824/1449 ...
# 825/1449 ...
# 826/1449 ...
# 827/1449 ...
# 828/1449 ...
# 829/1449 ...
# 830/1449 ...
# 831/1449 ...
# 832/1449 ...
# 833/1449 ...
# 834/1449 ...
# 835/1449 ...
# 836/1449 ...
# 837/1449 ...
# 838/1449 ...
# 839/1449 ...
# 840/1449 ...
# 841/1449 ...
# 842/1449 ...
# 843/1449 ...
# 844/1449 ...
# 845/1449 ...
# 846/1449 ...
# 847/1449 ...
# 848/1449 ...
# 849/1449 ...
# 850/1449 ...
# 851/1449 ...
# 852/1449 ...
# 853/1449 ...
# 854/1449 ...
# 855/1449 ...
# 856/1449 ...
# 857/1449 ...
# 858/1449 ...
# 859/1449 ...
# 860/1449 ...
# 861/1449 ...
# 862/1449 ...
# 863/1449 ...
# 864/1449 ...
# 865/1449 ...
# 866/1449 ...
# 867/1449 ...
# 868/1449 ...
# 869/1449 ...
# 870/1449 ...
# 871/1449 ...
# 872/1449 ...
# 873/1449 ...
# 874/1449 ...
# 875/1449 ...
# 876/1449 ...
# 877/1449 ...
# 878/1449 ...
# 879/1449 ...
# 880/1449 ...
# 881/1449 ...
# 882/1449 ...
# 883/1449 ...
# 884/1449 ...
# 885/1449 ...
# 886/1449 ...
# 887/1449 ...
# 888/1449 ...
# 889/1449 ...
# 890/1449 ...
# 891/1449 ...
# 892/1449 ...
# 893/1449 ...
# 894/1449 ...
# 895/1449 ...
# 896/1449 ...
# 897/1449 ...
# 898/1449 ...
# 899/1449 ...
# 900/1449 ...
# 901/1449 ...
# 902/1449 ...
# 903/1449 ...
# 904/1449 ...
# 905/1449 ...
# 906/1449 ...
# 907/1449 ...
# 908/1449 ...
# 909/1449 ...
# 910/1449 ...
# 911/1449 ...
# 912/1449 ...
# 913/1449 ...
# 914/1449 ...
# 915/1449 ...
# 916/1449 ...
# 917/1449 ...
# 918/1449 ...
# 919/1449 ...
# 920/1449 ...
# 921/1449 ...
# 922/1449 ...
# 923/1449 ...
# 924/1449 ...
# 925/1449 ...
# 926/1449 ...
# 927/1449 ...
# 928/1449 ...
# 929/1449 ...
# 930/1449 ...
# 931/1449 ...
# 932/1449 ...
# 933/1449 ...
# 934/1449 ...
# 935/1449 ...
# 936/1449 ...
# 937/1449 ...
# 938/1449 ...
# 939/1449 ...
# 940/1449 ...
# 941/1449 ...
# 942/1449 ...
# 943/1449 ...
# 944/1449 ...
# 945/1449 ...
# 946/1449 ...
# 947/1449 ...
# 948/1449 ...
# 949/1449 ...
# 950/1449 ...
# 951/1449 ...
# 952/1449 ...
# 953/1449 ...
# 954/1449 ...
# 955/1449 ...
# 956/1449 ...
# 957/1449 ...
# 958/1449 ...
# 959/1449 ...
# 960/1449 ...
# 961/1449 ...
# 962/1449 ...
# 963/1449 ...
# 964/1449 ...
# 965/1449 ...
# 966/1449 ...
# 967/1449 ...
# 968/1449 ...
# 969/1449 ...
# 970/1449 ...
# 971/1449 ...
# 972/1449 ...
# 973/1449 ...
# 974/1449 ...
# 975/1449 ...
# 976/1449 ...
# 977/1449 ...
# 978/1449 ...
# 979/1449 ...
# 980/1449 ...
# 981/1449 ...
# 982/1449 ...
# 983/1449 ...
# 984/1449 ...
# 985/1449 ...
# 986/1449 ...
# 987/1449 ...
# 988/1449 ...
# 989/1449 ...
# 990/1449 ...
# 991/1449 ...
# 992/1449 ...
# 993/1449 ...
# 994/1449 ...
# 995/1449 ...
# 996/1449 ...
# 997/1449 ...
# 998/1449 ...
# 999/1449 ...
# 1000/1449 ...
# 1001/1449 ...
# 1002/1449 ...
# 1003/1449 ...
# 1004/1449 ...
# 1005/1449 ...
# 1006/1449 ...
# 1007/1449 ...
# 1008/1449 ...
# 1009/1449 ...
# 1010/1449 ...
# 1011/1449 ...
# 1012/1449 ...
# 1013/1449 ...
# 1014/1449 ...
# 1015/1449 ...
# 1016/1449 ...
# 1017/1449 ...
# 1018/1449 ...
# 1019/1449 ...
# 1020/1449 ...
# 1021/1449 ...
# 1022/1449 ...
# 1023/1449 ...
# 1024/1449 ...
# 1025/1449 ...
# 1026/1449 ...
# 1027/1449 ...
# 1028/1449 ...
# 1029/1449 ...
# 1030/1449 ...
# 1031/1449 ...
# 1032/1449 ...
# 1033/1449 ...
# 1034/1449 ...
# 1035/1449 ...
# 1036/1449 ...
# 1037/1449 ...
# 1038/1449 ...
# 1039/1449 ...
# 1040/1449 ...
# 1041/1449 ...
# 1042/1449 ...
# 1043/1449 ...
# 1044/1449 ...
# 1045/1449 ...
# 1046/1449 ...
# 1047/1449 ...
# 1048/1449 ...
# 1049/1449 ...
# 1050/1449 ...
# 1051/1449 ...
# 1052/1449 ...
# 1053/1449 ...
# 1054/1449 ...
# 1055/1449 ...
# 1056/1449 ...
# 1057/1449 ...
# 1058/1449 ...
# 1059/1449 ...
# 1060/1449 ...
# 1061/1449 ...
# 1062/1449 ...
# 1063/1449 ...
# 1064/1449 ...
# 1065/1449 ...
# 1066/1449 ...
# 1067/1449 ...
# 1068/1449 ...
# 1069/1449 ...
# 1070/1449 ...
# 1071/1449 ...
# 1072/1449 ...
# 1073/1449 ...
# 1074/1449 ...
# 1075/1449 ...
# 1076/1449 ...
# 1077/1449 ...
# 1078/1449 ...
# 1079/1449 ...
# 1080/1449 ...
# 1081/1449 ...
# 1082/1449 ...
# 1083/1449 ...
# 1084/1449 ...
# 1085/1449 ...
# 1086/1449 ...
# 1087/1449 ...
# 1088/1449 ...
# 1089/1449 ...
# 1090/1449 ...
# 1091/1449 ...
# 1092/1449 ...
# 1093/1449 ...
# 1094/1449 ...
# 1095/1449 ...
# 1096/1449 ...
# 1097/1449 ...
# 1098/1449 ...
# 1099/1449 ...
# 1100/1449 ...
# 1101/1449 ...
# 1102/1449 ...
# 1103/1449 ...
# 1104/1449 ...
# 1105/1449 ...
# 1106/1449 ...
# 1107/1449 ...
# 1108/1449 ...
# 1109/1449 ...
# 1110/1449 ...
# 1111/1449 ...
# 1112/1449 ...
# 1113/1449 ...
# 1114/1449 ...
# 1115/1449 ...
# 1116/1449 ...
# 1117/1449 ...
# 1118/1449 ...
# 1119/1449 ...
# 1120/1449 ...
# 1121/1449 ...
# 1122/1449 ...
# 1123/1449 ...
# 1124/1449 ...
# 1125/1449 ...
# 1126/1449 ...
# 1127/1449 ...
# 1128/1449 ...
# 1129/1449 ...
# 1130/1449 ...
# 1131/1449 ...
# 1132/1449 ...
# 1133/1449 ...
# 1134/1449 ...
# 1135/1449 ...
# 1136/1449 ...
# 1137/1449 ...
# 1138/1449 ...
# 1139/1449 ...
# 1140/1449 ...
# 1141/1449 ...
# 1142/1449 ...
# 1143/1449 ...
# 1144/1449 ...
# 1145/1449 ...
# 1146/1449 ...
# 1147/1449 ...
# 1148/1449 ...
# 1149/1449 ...
# 1150/1449 ...
# 1151/1449 ...
# 1152/1449 ...
# 1153/1449 ...
# 1154/1449 ...
# 1155/1449 ...
# 1156/1449 ...
# 1157/1449 ...
# 1158/1449 ...
# 1159/1449 ...
# 1160/1449 ...
# 1161/1449 ...
# 1162/1449 ...
# 1163/1449 ...
# 1164/1449 ...
# 1165/1449 ...
# 1166/1449 ...
# 1167/1449 ...
# 1168/1449 ...
# 1169/1449 ...
# 1170/1449 ...
# 1171/1449 ...
# 1172/1449 ...
# 1173/1449 ...
# 1174/1449 ...
# 1175/1449 ...
# 1176/1449 ...
# 1177/1449 ...
# 1178/1449 ...
# 1179/1449 ...
# 1180/1449 ...
# 1181/1449 ...
# 1182/1449 ...
# 1183/1449 ...
# 1184/1449 ...
# 1185/1449 ...
# 1186/1449 ...
# 1187/1449 ...
# 1188/1449 ...
# 1189/1449 ...
# 1190/1449 ...
# 1191/1449 ...
# 1192/1449 ...
# 1193/1449 ...
# 1194/1449 ...
# 1195/1449 ...
# 1196/1449 ...
# 1197/1449 ...
# 1198/1449 ...
# 1199/1449 ...
# 1200/1449 ...
# 1201/1449 ...
# 1202/1449 ...
# 1203/1449 ...
# 1204/1449 ...
# 1205/1449 ...
# 1206/1449 ...
# 1207/1449 ...
# 1208/1449 ...
# 1209/1449 ...
# 1210/1449 ...
# 1211/1449 ...
# 1212/1449 ...
# 1213/1449 ...
# 1214/1449 ...
# 1215/1449 ...
# 1216/1449 ...
# 1217/1449 ...
# 1218/1449 ...
# 1219/1449 ...
# 1220/1449 ...
# 1221/1449 ...
# 1222/1449 ...
# 1223/1449 ...
# 1224/1449 ...
# 1225/1449 ...
# 1226/1449 ...
# 1227/1449 ...
# 1228/1449 ...
# 1229/1449 ...
# 1230/1449 ...
# 1231/1449 ...
# 1232/1449 ...
# 1233/1449 ...
# 1234/1449 ...
# 1235/1449 ...
# 1236/1449 ...
# 1237/1449 ...
# 1238/1449 ...
# 1239/1449 ...
# 1240/1449 ...
# 1241/1449 ...
# 1242/1449 ...
# 1243/1449 ...
# 1244/1449 ...
# 1245/1449 ...
# 1246/1449 ...
# 1247/1449 ...
# 1248/1449 ...
# 1249/1449 ...
# 1250/1449 ...
# 1251/1449 ...
# 1252/1449 ...
# 1253/1449 ...
# 1254/1449 ...
# 1255/1449 ...
# 1256/1449 ...
# 1257/1449 ...
# 1258/1449 ...
# 1259/1449 ...
# 1260/1449 ...
# 1261/1449 ...
# 1262/1449 ...
# 1263/1449 ...
# 1264/1449 ...
# 1265/1449 ...
# 1266/1449 ...
# 1267/1449 ...
# 1268/1449 ...
# 1269/1449 ...
# 1270/1449 ...
# 1271/1449 ...
# 1272/1449 ...
# 1273/1449 ...
# 1274/1449 ...
# 1275/1449 ...
# 1276/1449 ...
# 1277/1449 ...
# 1278/1449 ...
# 1279/1449 ...
# 1280/1449 ...
# 1281/1449 ...
# 1282/1449 ...
# 1283/1449 ...
# 1284/1449 ...
# 1285/1449 ...
# 1286/1449 ...
# 1287/1449 ...
# 1288/1449 ...
# 1289/1449 ...
# 1290/1449 ...
# 1291/1449 ...
# 1292/1449 ...
# 1293/1449 ...
# 1294/1449 ...
# 1295/1449 ...
# 1296/1449 ...
# 1297/1449 ...
# 1298/1449 ...
# 1299/1449 ...
# 1300/1449 ...
# 1301/1449 ...
# 1302/1449 ...
# 1303/1449 ...
# 1304/1449 ...
# 1305/1449 ...
# 1306/1449 ...
# 1307/1449 ...
# 1308/1449 ...
# 1309/1449 ...
# 1310/1449 ...
# 1311/1449 ...
# 1312/1449 ...
# 1313/1449 ...
# 1314/1449 ...
# 1315/1449 ...
# 1316/1449 ...
# 1317/1449 ...
# 1318/1449 ...
# 1319/1449 ...
# 1320/1449 ...
# 1321/1449 ...
# 1322/1449 ...
# 1323/1449 ...
# 1324/1449 ...
# 1325/1449 ...
# 1326/1449 ...
# 1327/1449 ...
# 1328/1449 ...
# 1329/1449 ...
# 1330/1449 ...
# 1331/1449 ...
# 1332/1449 ...
# 1333/1449 ...
# 1334/1449 ...
# 1335/1449 ...
# 1336/1449 ...
# 1337/1449 ...
# 1338/1449 ...
# 1339/1449 ...
# 1340/1449 ...
# 1341/1449 ...
# 1342/1449 ...
# 1343/1449 ...
# 1344/1449 ...
# 1345/1449 ...
# 1346/1449 ...
# 1347/1449 ...
# 1348/1449 ...
# 1349/1449 ...
# 1350/1449 ...
# 1351/1449 ...
# 1352/1449 ...
# 1353/1449 ...
# 1354/1449 ...
# 1355/1449 ...
# 1356/1449 ...
# 1357/1449 ...
# 1358/1449 ...
# 1359/1449 ...
# 1360/1449 ...
# 1361/1449 ...
# 1362/1449 ...
# 1363/1449 ...
# 1364/1449 ...
# 1365/1449 ...
# 1366/1449 ...
# 1367/1449 ...
# 1368/1449 ...
# 1369/1449 ...
# 1370/1449 ...
# 1371/1449 ...
# 1372/1449 ...
# 1373/1449 ...
# 1374/1449 ...
# 1375/1449 ...
# 1376/1449 ...
# 1377/1449 ...
# 1378/1449 ...
# 1379/1449 ...
# 1380/1449 ...
# 1381/1449 ...
# 1382/1449 ...
# 1383/1449 ...
# 1384/1449 ...
# 1385/1449 ...
# 1386/1449 ...
# 1387/1449 ...
# 1388/1449 ...
# 1389/1449 ...
# 1390/1449 ...
# 1391/1449 ...
# 1392/1449 ...
# 1393/1449 ...
# 1394/1449 ...
# 1395/1449 ...
# 1396/1449 ...
# 1397/1449 ...
# 1398/1449 ...
# 1399/1449 ...
# 1400/1449 ...
# 1401/1449 ...
# 1402/1449 ...
# 1403/1449 ...
# 1404/1449 ...
# 1405/1449 ...
# 1406/1449 ...
# 1407/1449 ...
# 1408/1449 ...
# 1409/1449 ...
# 1410/1449 ...
# 1411/1449 ...
# 1412/1449 ...
# 1413/1449 ...
# 1414/1449 ...
# 1415/1449 ...
# 1416/1449 ...
# 1417/1449 ...
# 1418/1449 ...
# 1419/1449 ...
# 1420/1449 ...
# 1421/1449 ...
# 1422/1449 ...
# 1423/1449 ...
# 1424/1449 ...
# 1425/1449 ...
# 1426/1449 ...
# 1427/1449 ...
# 1428/1449 ...
# 1429/1449 ...
# 1430/1449 ...
# 1431/1449 ...
# 1432/1449 ...
# 1433/1449 ...
# 1434/1449 ...
# 1435/1449 ...
# 1436/1449 ...
# 1437/1449 ...
# 1438/1449 ...
# 1439/1449 ...
# 1440/1449 ...
# 1441/1449 ...
# 1442/1449 ...
# 1443/1449 ...
# 1444/1449 ...
# 1445/1449 ...
# 1446/1449 ...
# 1447/1449 ...
# 1448/1449 ...
# 1449/1449 ...
# Mean iou =  0.4762409835558308
# 1/1449 ...
# 2/1449 ...
# 3/1449 ...
# 4/1449 ...
# 5/1449 ...
# 6/1449 ...
# 7/1449 ...
# 8/1449 ...
# 9/1449 ...
# 10/1449 ...
# 11/1449 ...
# 12/1449 ...
# 13/1449 ...
# 14/1449 ...
# 15/1449 ...
# 16/1449 ...
# 17/1449 ...
# 18/1449 ...
# 19/1449 ...
# 20/1449 ...
# 21/1449 ...
# 22/1449 ...
# 23/1449 ...
# 24/1449 ...
# 25/1449 ...
# 26/1449 ...
# 27/1449 ...
# 28/1449 ...
# 29/1449 ...
# 30/1449 ...
# 31/1449 ...
# 32/1449 ...
# 33/1449 ...
# 34/1449 ...
# 35/1449 ...
# 36/1449 ...
# 37/1449 ...
# 38/1449 ...
# 39/1449 ...
# 40/1449 ...
# 41/1449 ...
# 42/1449 ...
# 43/1449 ...
# 44/1449 ...
# 45/1449 ...
# 46/1449 ...
# 47/1449 ...
# 48/1449 ...
# 49/1449 ...
# 50/1449 ...
# 51/1449 ...
# 52/1449 ...
# 53/1449 ...
# 54/1449 ...
# 55/1449 ...
# 56/1449 ...
# 57/1449 ...
# 58/1449 ...
# 59/1449 ...
# 60/1449 ...
# 61/1449 ...
# 62/1449 ...
# 63/1449 ...
# 64/1449 ...
# 65/1449 ...
# 66/1449 ...
# 67/1449 ...
# 68/1449 ...
# 69/1449 ...
# 70/1449 ...
# 71/1449 ...
# 72/1449 ...
# 73/1449 ...
# 74/1449 ...
# 75/1449 ...
# 76/1449 ...
# 77/1449 ...
# 78/1449 ...
# 79/1449 ...
# 80/1449 ...
# 81/1449 ...
# 82/1449 ...
# 83/1449 ...
# 84/1449 ...
# 85/1449 ...
# 86/1449 ...
# 87/1449 ...
# 88/1449 ...
# 89/1449 ...
# 90/1449 ...
# 91/1449 ...
# 92/1449 ...
# 93/1449 ...
# 94/1449 ...
# 95/1449 ...
# 96/1449 ...
# 97/1449 ...
# 98/1449 ...
# 99/1449 ...
# 100/1449 ...
# 101/1449 ...
# 102/1449 ...
# 103/1449 ...
# 104/1449 ...
# 105/1449 ...
# 106/1449 ...
# 107/1449 ...
# 108/1449 ...
# 109/1449 ...
# 110/1449 ...
# 111/1449 ...
# 112/1449 ...
# 113/1449 ...
# 114/1449 ...
# 115/1449 ...
# 116/1449 ...
# 117/1449 ...
# 118/1449 ...
# 119/1449 ...
# 120/1449 ...
# 121/1449 ...
# 122/1449 ...
# 123/1449 ...
# 124/1449 ...
# 125/1449 ...
# 126/1449 ...
# 127/1449 ...
# 128/1449 ...
# 129/1449 ...
# 130/1449 ...
# 131/1449 ...
# 132/1449 ...
# 133/1449 ...
# 134/1449 ...
# 135/1449 ...
# 136/1449 ...
# 137/1449 ...
# 138/1449 ...
# 139/1449 ...
# 140/1449 ...
# 141/1449 ...
# 142/1449 ...
# 143/1449 ...
# 144/1449 ...
# 145/1449 ...
# 146/1449 ...
# 147/1449 ...
# 148/1449 ...
# 149/1449 ...
# 150/1449 ...
# 151/1449 ...
# 152/1449 ...
# 153/1449 ...
# 154/1449 ...
# 155/1449 ...
# 156/1449 ...
# 157/1449 ...
# 158/1449 ...
# 159/1449 ...
# 160/1449 ...
# 161/1449 ...
# 162/1449 ...
# 163/1449 ...
# 164/1449 ...
# 165/1449 ...
# 166/1449 ...
# 167/1449 ...
# 168/1449 ...
# 169/1449 ...
# 170/1449 ...
# 171/1449 ...
# 172/1449 ...
# 173/1449 ...
# 174/1449 ...
# 175/1449 ...
# 176/1449 ...
# 177/1449 ...
# 178/1449 ...
# 179/1449 ...
# 180/1449 ...
# 181/1449 ...
# 182/1449 ...
# 183/1449 ...
# 184/1449 ...
# 185/1449 ...
# 186/1449 ...
# 187/1449 ...
# 188/1449 ...
# 189/1449 ...
# 190/1449 ...
# 191/1449 ...
# 192/1449 ...
# 193/1449 ...
# 194/1449 ...
# 195/1449 ...
# 196/1449 ...
# 197/1449 ...
# 198/1449 ...
# 199/1449 ...
# 200/1449 ...
# 201/1449 ...
# 202/1449 ...
# 203/1449 ...
# 204/1449 ...
# 205/1449 ...
# 206/1449 ...
# 207/1449 ...
# 208/1449 ...
# 209/1449 ...
# 210/1449 ...
# 211/1449 ...
# 212/1449 ...
# 213/1449 ...
# 214/1449 ...
# 215/1449 ...
# 216/1449 ...
# 217/1449 ...
# 218/1449 ...
# 219/1449 ...
# 220/1449 ...
# 221/1449 ...
# 222/1449 ...
# 223/1449 ...
# 224/1449 ...
# 225/1449 ...
# 226/1449 ...
# 227/1449 ...
# 228/1449 ...
# 229/1449 ...
# 230/1449 ...
# 231/1449 ...
# 232/1449 ...
# 233/1449 ...
# 234/1449 ...
# 235/1449 ...
# 236/1449 ...
# 237/1449 ...
# 238/1449 ...
# 239/1449 ...
# 240/1449 ...
# 241/1449 ...
# 242/1449 ...
# 243/1449 ...
# 244/1449 ...
# 245/1449 ...
# 246/1449 ...
# 247/1449 ...
# 248/1449 ...
# 249/1449 ...
# 250/1449 ...
# 251/1449 ...
# 252/1449 ...
# 253/1449 ...
# 254/1449 ...
# 255/1449 ...
# 256/1449 ...
# 257/1449 ...
# 258/1449 ...
# 259/1449 ...
# 260/1449 ...
# 261/1449 ...
# 262/1449 ...
# 263/1449 ...
# 264/1449 ...
# 265/1449 ...
# 266/1449 ...
# 267/1449 ...
# 268/1449 ...
# 269/1449 ...
# 270/1449 ...
# 271/1449 ...
# 272/1449 ...
# 273/1449 ...
# 274/1449 ...
# 275/1449 ...
# 276/1449 ...
# 277/1449 ...
# 278/1449 ...
# 279/1449 ...
# 280/1449 ...
# 281/1449 ...
# 282/1449 ...
# 283/1449 ...
# 284/1449 ...
# 285/1449 ...
# 286/1449 ...
# 287/1449 ...
# 288/1449 ...
# 289/1449 ...
# 290/1449 ...
# 291/1449 ...
# 292/1449 ...
# 293/1449 ...
# 294/1449 ...
# 295/1449 ...
# 296/1449 ...
# 297/1449 ...
# 298/1449 ...
# 299/1449 ...
# 300/1449 ...
# 301/1449 ...
# 302/1449 ...
# 303/1449 ...
# 304/1449 ...
# 305/1449 ...
# 306/1449 ...
# 307/1449 ...
# 308/1449 ...
# 309/1449 ...
# 310/1449 ...
# 311/1449 ...
# 312/1449 ...
# 313/1449 ...
# 314/1449 ...
# 315/1449 ...
# 316/1449 ...
# 317/1449 ...
# 318/1449 ...
# 319/1449 ...
# 320/1449 ...
# 321/1449 ...
# 322/1449 ...
# 323/1449 ...
# 324/1449 ...
# 325/1449 ...
# 326/1449 ...
# 327/1449 ...
# 328/1449 ...
# 329/1449 ...
# 330/1449 ...
# 331/1449 ...
# 332/1449 ...
# 333/1449 ...
# 334/1449 ...
# 335/1449 ...
# 336/1449 ...
# 337/1449 ...
# 338/1449 ...
# 339/1449 ...
# 340/1449 ...
# 341/1449 ...
# 342/1449 ...
# 343/1449 ...
# 344/1449 ...
# 345/1449 ...
# 346/1449 ...
# 347/1449 ...
# 348/1449 ...
# 349/1449 ...
# 350/1449 ...
# 351/1449 ...
# 352/1449 ...
# 353/1449 ...
# 354/1449 ...
# 355/1449 ...
# 356/1449 ...
# 357/1449 ...
# 358/1449 ...
# 359/1449 ...
# 360/1449 ...
# 361/1449 ...
# 362/1449 ...
# 363/1449 ...
# 364/1449 ...
# 365/1449 ...
# 366/1449 ...
# 367/1449 ...
# 368/1449 ...
# 369/1449 ...
# 370/1449 ...
# 371/1449 ...
# 372/1449 ...
# 373/1449 ...
# 374/1449 ...
# 375/1449 ...
# 376/1449 ...
# 377/1449 ...
# 378/1449 ...
# 379/1449 ...
# 380/1449 ...
# 381/1449 ...
# 382/1449 ...
# 383/1449 ...
# 384/1449 ...
# 385/1449 ...
# 386/1449 ...
# 387/1449 ...
# 388/1449 ...
# 389/1449 ...
# 390/1449 ...
# 391/1449 ...
# 392/1449 ...
# 393/1449 ...
# 394/1449 ...
# 395/1449 ...
# 396/1449 ...
# 397/1449 ...
# 398/1449 ...
# 399/1449 ...
# 400/1449 ...
# 401/1449 ...
# 402/1449 ...
# 403/1449 ...
# 404/1449 ...
# 405/1449 ...
# 406/1449 ...
# 407/1449 ...
# 408/1449 ...
# 409/1449 ...
# 410/1449 ...
# 411/1449 ...
# 412/1449 ...
# 413/1449 ...
# 414/1449 ...
# 415/1449 ...
# 416/1449 ...
# 417/1449 ...
# 418/1449 ...
# 419/1449 ...
# 420/1449 ...
# 421/1449 ...
# 422/1449 ...
# 423/1449 ...
# 424/1449 ...
# 425/1449 ...
# 426/1449 ...
# 427/1449 ...
# 428/1449 ...
# 429/1449 ...
# 430/1449 ...
# 431/1449 ...
# 432/1449 ...
# 433/1449 ...
# 434/1449 ...
# 435/1449 ...
# 436/1449 ...
# 437/1449 ...
# 438/1449 ...
# 439/1449 ...
# 440/1449 ...
# 441/1449 ...
# 442/1449 ...
# 443/1449 ...
# 444/1449 ...
# 445/1449 ...
# 446/1449 ...
# 447/1449 ...
# 448/1449 ...
# 449/1449 ...
# 450/1449 ...
# 451/1449 ...
# 452/1449 ...
# 453/1449 ...
# 454/1449 ...
# 455/1449 ...
# 456/1449 ...
# 457/1449 ...
# 458/1449 ...
# 459/1449 ...
# 460/1449 ...
# 461/1449 ...
# 462/1449 ...
# 463/1449 ...
# 464/1449 ...
# 465/1449 ...
# 466/1449 ...
# 467/1449 ...
# 468/1449 ...
# 469/1449 ...
# 470/1449 ...
# 471/1449 ...
# 472/1449 ...
# 473/1449 ...
# 474/1449 ...
# 475/1449 ...
# 476/1449 ...
# 477/1449 ...
# 478/1449 ...
# 479/1449 ...
# 480/1449 ...
# 481/1449 ...
# 482/1449 ...
# 483/1449 ...
# 484/1449 ...
# 485/1449 ...
# 486/1449 ...
# 487/1449 ...
# 488/1449 ...
# 489/1449 ...
# 490/1449 ...
# 491/1449 ...
# 492/1449 ...
# 493/1449 ...
# 494/1449 ...
# 495/1449 ...
# 496/1449 ...
# 497/1449 ...
# 498/1449 ...
# 499/1449 ...
# 500/1449 ...
# 501/1449 ...
# 502/1449 ...
# 503/1449 ...
# 504/1449 ...
# 505/1449 ...
# 506/1449 ...
# 507/1449 ...
# 508/1449 ...
# 509/1449 ...
# 510/1449 ...
# 511/1449 ...
# 512/1449 ...
# 513/1449 ...
# 514/1449 ...
# 515/1449 ...
# 516/1449 ...
# 517/1449 ...
# 518/1449 ...
# 519/1449 ...
# 520/1449 ...
# 521/1449 ...
# 522/1449 ...
# 523/1449 ...
# 524/1449 ...
# 525/1449 ...
# 526/1449 ...
# 527/1449 ...
# 528/1449 ...
# 529/1449 ...
# 530/1449 ...
# 531/1449 ...
# 532/1449 ...
# 533/1449 ...
# 534/1449 ...
# 535/1449 ...
# 536/1449 ...
# 537/1449 ...
# 538/1449 ...
# 539/1449 ...
# 540/1449 ...
# 541/1449 ...
# 542/1449 ...
# 543/1449 ...
# 544/1449 ...
# 545/1449 ...
# 546/1449 ...
# 547/1449 ...
# 548/1449 ...
# 549/1449 ...
# 550/1449 ...
# 551/1449 ...
# 552/1449 ...
# 553/1449 ...
# 554/1449 ...
# 555/1449 ...
# 556/1449 ...
# 557/1449 ...
# 558/1449 ...
# 559/1449 ...
# 560/1449 ...
# 561/1449 ...
# 562/1449 ...
# 563/1449 ...
# 564/1449 ...
# 565/1449 ...
# 566/1449 ...
# 567/1449 ...
# 568/1449 ...
# 569/1449 ...
# 570/1449 ...
# 571/1449 ...
# 572/1449 ...
# 573/1449 ...
# 574/1449 ...
# 575/1449 ...
# 576/1449 ...
# 577/1449 ...
# 578/1449 ...
# 579/1449 ...
# 580/1449 ...
# 581/1449 ...
# 582/1449 ...
# 583/1449 ...
# 584/1449 ...
# 585/1449 ...
# 586/1449 ...
# 587/1449 ...
# 588/1449 ...
# 589/1449 ...
# 590/1449 ...
# 591/1449 ...
# 592/1449 ...
# 593/1449 ...
# 594/1449 ...
# 595/1449 ...
# 596/1449 ...
# 597/1449 ...
# 598/1449 ...
# 599/1449 ...
# 600/1449 ...
# 601/1449 ...
# 602/1449 ...
# 603/1449 ...
# 604/1449 ...
# 605/1449 ...
# 606/1449 ...
# 607/1449 ...
# 608/1449 ...
# 609/1449 ...
# 610/1449 ...
# 611/1449 ...
# 612/1449 ...
# 613/1449 ...
# 614/1449 ...
# 615/1449 ...
# 616/1449 ...
# 617/1449 ...
# 618/1449 ...
# 619/1449 ...
# 620/1449 ...
# 621/1449 ...
# 622/1449 ...
# 623/1449 ...
# 624/1449 ...
# 625/1449 ...
# 626/1449 ...
# 627/1449 ...
# 628/1449 ...
# 629/1449 ...
# 630/1449 ...
# 631/1449 ...
# 632/1449 ...
# 633/1449 ...
# 634/1449 ...
# 635/1449 ...
# 636/1449 ...
# 637/1449 ...
# 638/1449 ...
# 639/1449 ...
# 640/1449 ...
# 641/1449 ...
# 642/1449 ...
# 643/1449 ...
# 644/1449 ...
# 645/1449 ...
# 646/1449 ...
# 647/1449 ...
# 648/1449 ...
# 649/1449 ...
# 650/1449 ...
# 651/1449 ...
# 652/1449 ...
# 653/1449 ...
# 654/1449 ...
# 655/1449 ...
# 656/1449 ...
# 657/1449 ...
# 658/1449 ...
# 659/1449 ...
# 660/1449 ...
# 661/1449 ...
# 662/1449 ...
# 663/1449 ...
# 664/1449 ...
# 665/1449 ...
# 666/1449 ...
# 667/1449 ...
# 668/1449 ...
# 669/1449 ...
# 670/1449 ...
# 671/1449 ...
# 672/1449 ...
# 673/1449 ...
# 674/1449 ...
# 675/1449 ...
# 676/1449 ...
# 677/1449 ...
# 678/1449 ...
# 679/1449 ...
# 680/1449 ...
# 681/1449 ...
# 682/1449 ...
# 683/1449 ...
# 684/1449 ...
# 685/1449 ...
# 686/1449 ...
# 687/1449 ...
# 688/1449 ...
# 689/1449 ...
# 690/1449 ...
# 691/1449 ...
# 692/1449 ...
# 693/1449 ...
# 694/1449 ...
# 695/1449 ...
# 696/1449 ...
# 697/1449 ...
# 698/1449 ...
# 699/1449 ...
# 700/1449 ...
# 701/1449 ...
# 702/1449 ...
# 703/1449 ...
# 704/1449 ...
# 705/1449 ...
# 706/1449 ...
# 707/1449 ...
# 708/1449 ...
# 709/1449 ...
# 710/1449 ...
# 711/1449 ...
# 712/1449 ...
# 713/1449 ...
# 714/1449 ...
# 715/1449 ...
# 716/1449 ...
# 717/1449 ...
# 718/1449 ...
# 719/1449 ...
# 720/1449 ...
# 721/1449 ...
# 722/1449 ...
# 723/1449 ...
# 724/1449 ...
# 725/1449 ...
# 726/1449 ...
# 727/1449 ...
# 728/1449 ...
# 729/1449 ...
# 730/1449 ...
# 731/1449 ...
# 732/1449 ...
# 733/1449 ...
# 734/1449 ...
# 735/1449 ...
# 736/1449 ...
# 737/1449 ...
# 738/1449 ...
# 739/1449 ...
# 740/1449 ...
# 741/1449 ...
# 742/1449 ...
# 743/1449 ...
# 744/1449 ...
# 745/1449 ...
# 746/1449 ...
# 747/1449 ...
# 748/1449 ...
# 749/1449 ...
# 750/1449 ...
# 751/1449 ...
# 752/1449 ...
# 753/1449 ...
# 754/1449 ...
# 755/1449 ...
# 756/1449 ...
# 757/1449 ...
# 758/1449 ...
# 759/1449 ...
# 760/1449 ...
# 761/1449 ...
# 762/1449 ...
# 763/1449 ...
# 764/1449 ...
# 765/1449 ...
# 766/1449 ...
# 767/1449 ...
# 768/1449 ...
# 769/1449 ...
# 770/1449 ...
# 771/1449 ...
# 772/1449 ...
# 773/1449 ...
# 774/1449 ...
# 775/1449 ...
# 776/1449 ...
# 777/1449 ...
# 778/1449 ...
# 779/1449 ...
# 780/1449 ...
# 781/1449 ...
# 782/1449 ...
# 783/1449 ...
# 784/1449 ...
# 785/1449 ...
# 786/1449 ...
# 787/1449 ...
# 788/1449 ...
# 789/1449 ...
# 790/1449 ...
# 791/1449 ...
# 792/1449 ...
# 793/1449 ...
# 794/1449 ...
# 795/1449 ...
# 796/1449 ...
# 797/1449 ...
# 798/1449 ...
# 799/1449 ...
# 800/1449 ...
# 801/1449 ...
# 802/1449 ...
# 803/1449 ...
# 804/1449 ...
# 805/1449 ...
# 806/1449 ...
# 807/1449 ...
# 808/1449 ...
# 809/1449 ...
# 810/1449 ...
# 811/1449 ...
# 812/1449 ...
# 813/1449 ...
# 814/1449 ...
# 815/1449 ...
# 816/1449 ...
# 817/1449 ...
# 818/1449 ...
# 819/1449 ...
# 820/1449 ...
# 821/1449 ...
# 822/1449 ...
# 823/1449 ...
# 824/1449 ...
# 825/1449 ...
# 826/1449 ...
# 827/1449 ...
# 828/1449 ...
# 829/1449 ...
# 830/1449 ...
# 831/1449 ...
# 832/1449 ...
# 833/1449 ...
# 834/1449 ...
# 835/1449 ...
# 836/1449 ...
# 837/1449 ...
# 838/1449 ...
# 839/1449 ...
# 840/1449 ...
# 841/1449 ...
# 842/1449 ...
# 843/1449 ...
# 844/1449 ...
# 845/1449 ...
# 846/1449 ...
# 847/1449 ...
# 848/1449 ...
# 849/1449 ...
# 850/1449 ...
# 851/1449 ...
# 852/1449 ...
# 853/1449 ...
# 854/1449 ...
# 855/1449 ...
# 856/1449 ...
# 857/1449 ...
# 858/1449 ...
# 859/1449 ...
# 860/1449 ...
# 861/1449 ...
# 862/1449 ...
# 863/1449 ...
# 864/1449 ...
# 865/1449 ...
# 866/1449 ...
# 867/1449 ...
# 868/1449 ...
# 869/1449 ...
# 870/1449 ...
# 871/1449 ...
# 872/1449 ...
# 873/1449 ...
# 874/1449 ...
# 875/1449 ...
# 876/1449 ...
# 877/1449 ...
# 878/1449 ...
# 879/1449 ...
# 880/1449 ...
# 881/1449 ...
# 882/1449 ...
# 883/1449 ...
# 884/1449 ...
# 885/1449 ...
# 886/1449 ...
# 887/1449 ...
# 888/1449 ...
# 889/1449 ...
# 890/1449 ...
# 891/1449 ...
# 892/1449 ...
# 893/1449 ...
# 894/1449 ...
# 895/1449 ...
# 896/1449 ...
# 897/1449 ...
# 898/1449 ...
# 899/1449 ...
# 900/1449 ...
# 901/1449 ...
# 902/1449 ...
# 903/1449 ...
# 904/1449 ...
# 905/1449 ...
# 906/1449 ...
# 907/1449 ...
# 908/1449 ...
# 909/1449 ...
# 910/1449 ...
# 911/1449 ...
# 912/1449 ...
# 913/1449 ...
# 914/1449 ...
# 915/1449 ...
# 916/1449 ...
# 917/1449 ...
# 918/1449 ...
# 919/1449 ...
# 920/1449 ...
# 921/1449 ...
# 922/1449 ...
# 923/1449 ...
# 924/1449 ...
# 925/1449 ...
# 926/1449 ...
# 927/1449 ...
# 928/1449 ...
# 929/1449 ...
# 930/1449 ...
# 931/1449 ...
# 932/1449 ...
# 933/1449 ...
# 934/1449 ...
# 935/1449 ...
# 936/1449 ...
# 937/1449 ...
# 938/1449 ...
# 939/1449 ...
# 940/1449 ...
# 941/1449 ...
# 942/1449 ...
# 943/1449 ...
# 944/1449 ...
# 945/1449 ...
# 946/1449 ...
# 947/1449 ...
# 948/1449 ...
# 949/1449 ...
# 950/1449 ...
# 951/1449 ...
# 952/1449 ...
# 953/1449 ...
# 954/1449 ...
# 955/1449 ...
# 956/1449 ...
# 957/1449 ...
# 958/1449 ...
# 959/1449 ...
# 960/1449 ...
# 961/1449 ...
# 962/1449 ...
# 963/1449 ...
# 964/1449 ...
# 965/1449 ...
# 966/1449 ...
# 967/1449 ...
# 968/1449 ...
# 969/1449 ...
# 970/1449 ...
# 971/1449 ...
# 972/1449 ...
# 973/1449 ...
# 974/1449 ...
# 975/1449 ...
# 976/1449 ...
# 977/1449 ...
# 978/1449 ...
# 979/1449 ...
# 980/1449 ...
# 981/1449 ...
# 982/1449 ...
# 983/1449 ...
# 984/1449 ...
# 985/1449 ...
# 986/1449 ...
# 987/1449 ...
# 988/1449 ...
# 989/1449 ...
# 990/1449 ...
# 991/1449 ...
# 992/1449 ...
# 993/1449 ...
# 994/1449 ...
# 995/1449 ...
# 996/1449 ...
# 997/1449 ...
# 998/1449 ...
# 999/1449 ...
# 1000/1449 ...
# 1001/1449 ...
# 1002/1449 ...
# 1003/1449 ...
# 1004/1449 ...
# 1005/1449 ...
# 1006/1449 ...
# 1007/1449 ...
# 1008/1449 ...
# 1009/1449 ...
# 1010/1449 ...
# 1011/1449 ...
# 1012/1449 ...
# 1013/1449 ...
# 1014/1449 ...
# 1015/1449 ...
# 1016/1449 ...
# 1017/1449 ...
# 1018/1449 ...
# 1019/1449 ...
# 1020/1449 ...
# 1021/1449 ...
# 1022/1449 ...
# 1023/1449 ...
# 1024/1449 ...
# 1025/1449 ...
# 1026/1449 ...
# 1027/1449 ...
# 1028/1449 ...
# 1029/1449 ...
# 1030/1449 ...
# 1031/1449 ...
# 1032/1449 ...
# 1033/1449 ...
# 1034/1449 ...
# 1035/1449 ...
# 1036/1449 ...
# 1037/1449 ...
# 1038/1449 ...
# 1039/1449 ...
# 1040/1449 ...
# 1041/1449 ...
# 1042/1449 ...
# 1043/1449 ...
# 1044/1449 ...
# 1045/1449 ...
# 1046/1449 ...
# 1047/1449 ...
# 1048/1449 ...
# 1049/1449 ...
# 1050/1449 ...
# 1051/1449 ...
# 1052/1449 ...
# 1053/1449 ...
# 1054/1449 ...
# 1055/1449 ...
# 1056/1449 ...
# 1057/1449 ...
# 1058/1449 ...
# 1059/1449 ...
# 1060/1449 ...
# 1061/1449 ...
# 1062/1449 ...
# 1063/1449 ...
# 1064/1449 ...
# 1065/1449 ...
# 1066/1449 ...
# 1067/1449 ...
# 1068/1449 ...
# 1069/1449 ...
# 1070/1449 ...
# 1071/1449 ...
# 1072/1449 ...
# 1073/1449 ...
# 1074/1449 ...
# 1075/1449 ...
# 1076/1449 ...
# 1077/1449 ...
# 1078/1449 ...
# 1079/1449 ...
# 1080/1449 ...
# 1081/1449 ...
# 1082/1449 ...
# 1083/1449 ...
# 1084/1449 ...
# 1085/1449 ...
# 1086/1449 ...
# 1087/1449 ...
# 1088/1449 ...
# 1089/1449 ...
# 1090/1449 ...
# 1091/1449 ...
# 1092/1449 ...
# 1093/1449 ...
# 1094/1449 ...
# 1095/1449 ...
# 1096/1449 ...
# 1097/1449 ...
# 1098/1449 ...
# 1099/1449 ...
# 1100/1449 ...
# 1101/1449 ...
# 1102/1449 ...
# 1103/1449 ...
# 1104/1449 ...
# 1105/1449 ...
# 1106/1449 ...
# 1107/1449 ...
# 1108/1449 ...
# 1109/1449 ...
# 1110/1449 ...
# 1111/1449 ...
# 1112/1449 ...
# 1113/1449 ...
# 1114/1449 ...
# 1115/1449 ...
# 1116/1449 ...
# 1117/1449 ...
# 1118/1449 ...
# 1119/1449 ...
# 1120/1449 ...
# 1121/1449 ...
# 1122/1449 ...
# 1123/1449 ...
# 1124/1449 ...
# 1125/1449 ...
# 1126/1449 ...
# 1127/1449 ...
# 1128/1449 ...
# 1129/1449 ...
# 1130/1449 ...
# 1131/1449 ...
# 1132/1449 ...
# 1133/1449 ...
# 1134/1449 ...
# 1135/1449 ...
# 1136/1449 ...
# 1137/1449 ...
# 1138/1449 ...
# 1139/1449 ...
# 1140/1449 ...
# 1141/1449 ...
# 1142/1449 ...
# 1143/1449 ...
# 1144/1449 ...
# 1145/1449 ...
# 1146/1449 ...
# 1147/1449 ...
# 1148/1449 ...
# 1149/1449 ...
# 1150/1449 ...
# 1151/1449 ...
# 1152/1449 ...
# 1153/1449 ...
# 1154/1449 ...
# 1155/1449 ...
# 1156/1449 ...
# 1157/1449 ...
# 1158/1449 ...
# 1159/1449 ...
# 1160/1449 ...
# 1161/1449 ...
# 1162/1449 ...
# 1163/1449 ...
# 1164/1449 ...
# 1165/1449 ...
# 1166/1449 ...
# 1167/1449 ...
# 1168/1449 ...
# 1169/1449 ...
# 1170/1449 ...
# 1171/1449 ...
# 1172/1449 ...
# 1173/1449 ...
# 1174/1449 ...
# 1175/1449 ...
# 1176/1449 ...
# 1177/1449 ...
# 1178/1449 ...
# 1179/1449 ...
# 1180/1449 ...
# 1181/1449 ...
# 1182/1449 ...
# 1183/1449 ...
# 1184/1449 ...
# 1185/1449 ...
# 1186/1449 ...
# 1187/1449 ...
# 1188/1449 ...
# 1189/1449 ...
# 1190/1449 ...
# 1191/1449 ...
# 1192/1449 ...
# 1193/1449 ...
# 1194/1449 ...
# 1195/1449 ...
# 1196/1449 ...
# 1197/1449 ...
# 1198/1449 ...
# 1199/1449 ...
# 1200/1449 ...
# 1201/1449 ...
# 1202/1449 ...
# 1203/1449 ...
# 1204/1449 ...
# 1205/1449 ...
# 1206/1449 ...
# 1207/1449 ...
# 1208/1449 ...
# 1209/1449 ...
# 1210/1449 ...
# 1211/1449 ...
# 1212/1449 ...
# 1213/1449 ...
# 1214/1449 ...
# 1215/1449 ...
# 1216/1449 ...
# 1217/1449 ...
# 1218/1449 ...
# 1219/1449 ...
# 1220/1449 ...
# 1221/1449 ...
# 1222/1449 ...
# 1223/1449 ...
# 1224/1449 ...
# 1225/1449 ...
# 1226/1449 ...
# 1227/1449 ...
# 1228/1449 ...
# 1229/1449 ...
# 1230/1449 ...
# 1231/1449 ...
# 1232/1449 ...
# 1233/1449 ...
# 1234/1449 ...
# 1235/1449 ...
# 1236/1449 ...
# 1237/1449 ...
# 1238/1449 ...
# 1239/1449 ...
# 1240/1449 ...
# 1241/1449 ...
# 1242/1449 ...
# 1243/1449 ...
# 1244/1449 ...
# 1245/1449 ...
# 1246/1449 ...
# 1247/1449 ...
# 1248/1449 ...
# 1249/1449 ...
# 1250/1449 ...
# 1251/1449 ...
# 1252/1449 ...
# 1253/1449 ...
# 1254/1449 ...
# 1255/1449 ...
# 1256/1449 ...
# 1257/1449 ...
# 1258/1449 ...
# 1259/1449 ...
# 1260/1449 ...
# 1261/1449 ...
# 1262/1449 ...
# 1263/1449 ...
# 1264/1449 ...
# 1265/1449 ...
# 1266/1449 ...
# 1267/1449 ...
# 1268/1449 ...
# 1269/1449 ...
# 1270/1449 ...
# 1271/1449 ...
# 1272/1449 ...
# 1273/1449 ...
# 1274/1449 ...
# 1275/1449 ...
# 1276/1449 ...
# 1277/1449 ...
# 1278/1449 ...
# 1279/1449 ...
# 1280/1449 ...
# 1281/1449 ...
# 1282/1449 ...
# 1283/1449 ...
# 1284/1449 ...
# 1285/1449 ...
# 1286/1449 ...
# 1287/1449 ...
# 1288/1449 ...
# 1289/1449 ...
# 1290/1449 ...
# 1291/1449 ...
# 1292/1449 ...
# 1293/1449 ...
# 1294/1449 ...
# 1295/1449 ...
# 1296/1449 ...
# 1297/1449 ...
# 1298/1449 ...
# 1299/1449 ...
# 1300/1449 ...
# 1301/1449 ...
# 1302/1449 ...
# 1303/1449 ...
# 1304/1449 ...
# 1305/1449 ...
# 1306/1449 ...
# 1307/1449 ...
# 1308/1449 ...
# 1309/1449 ...
# 1310/1449 ...
# 1311/1449 ...
# 1312/1449 ...
# 1313/1449 ...
# 1314/1449 ...
# 1315/1449 ...
# 1316/1449 ...
# 1317/1449 ...
# 1318/1449 ...
# 1319/1449 ...
# 1320/1449 ...
# 1321/1449 ...
# 1322/1449 ...
# 1323/1449 ...
# 1324/1449 ...
# 1325/1449 ...
# 1326/1449 ...
# 1327/1449 ...
# 1328/1449 ...
# 1329/1449 ...
# 1330/1449 ...
# 1331/1449 ...
# 1332/1449 ...
# 1333/1449 ...
# 1334/1449 ...
# 1335/1449 ...
# 1336/1449 ...
# 1337/1449 ...
# 1338/1449 ...
# 1339/1449 ...
# 1340/1449 ...
# 1341/1449 ...
# 1342/1449 ...
# 1343/1449 ...
# 1344/1449 ...
# 1345/1449 ...
# 1346/1449 ...
# 1347/1449 ...
# 1348/1449 ...
# 1349/1449 ...
# 1350/1449 ...
# 1351/1449 ...
# 1352/1449 ...
# 1353/1449 ...
# 1354/1449 ...
# 1355/1449 ...
# 1356/1449 ...
# 1357/1449 ...
# 1358/1449 ...
# 1359/1449 ...
# 1360/1449 ...
# 1361/1449 ...
# 1362/1449 ...
# 1363/1449 ...
# 1364/1449 ...
# 1365/1449 ...
# 1366/1449 ...
# 1367/1449 ...
# 1368/1449 ...
# 1369/1449 ...
# 1370/1449 ...
# 1371/1449 ...
# 1372/1449 ...
# 1373/1449 ...
# 1374/1449 ...
# 1375/1449 ...
# 1376/1449 ...
# 1377/1449 ...
# 1378/1449 ...
# 1379/1449 ...
# 1380/1449 ...
# 1381/1449 ...
# 1382/1449 ...
# 1383/1449 ...
# 1384/1449 ...
# 1385/1449 ...
# 1386/1449 ...
# 1387/1449 ...
# 1388/1449 ...
# 1389/1449 ...
# 1390/1449 ...
# 1391/1449 ...
# 1392/1449 ...
# 1393/1449 ...
# 1394/1449 ...
# 1395/1449 ...
# 1396/1449 ...
# 1397/1449 ...
# 1398/1449 ...
# 1399/1449 ...
# 1400/1449 ...
# 1401/1449 ...
# 1402/1449 ...
# 1403/1449 ...
# 1404/1449 ...
# 1405/1449 ...
# 1406/1449 ...
# 1407/1449 ...
# 1408/1449 ...
# 1409/1449 ...
# 1410/1449 ...
# 1411/1449 ...
# 1412/1449 ...
# 1413/1449 ...
# 1414/1449 ...
# 1415/1449 ...
# 1416/1449 ...
# 1417/1449 ...
# 1418/1449 ...
# 1419/1449 ...
# 1420/1449 ...
# 1421/1449 ...
# 1422/1449 ...
# 1423/1449 ...
# 1424/1449 ...
# 1425/1449 ...
# 1426/1449 ...
# 1427/1449 ...
# 1428/1449 ...
# 1429/1449 ...
# 1430/1449 ...
# 1431/1449 ...
# 1432/1449 ...
# 1433/1449 ...
# 1434/1449 ...
# 1435/1449 ...
# 1436/1449 ...
# 1437/1449 ...
# 1438/1449 ...
# 1439/1449 ...
# 1440/1449 ...
# 1441/1449 ...
# 1442/1449 ...
# 1443/1449 ...
# 1444/1449 ...
# 1445/1449 ...
# 1446/1449 ...
# 1447/1449 ...
# 1448/1449 ...
# 1449/1449 ...
# Mean iou =  0.4427606294206825

# %%
print('Mean IoU of model FCN-8s is:', fcn8s_miou)
print('Mean IoU of model bilinear upsampled VGG-16 is:', bilinearVgg_miou)
# Out:
# Mean IoU of model FCN-8s is: 0.4762409835558308
# Mean IoU of model bilinear upsampled VGG-16 is: 0.4427606294206825

# %%
# Visualize the result
#############
# CODE HERE #
############# 
img_num = 3

img =[]
img_norm = []
img.append(test_conv)
img_norm.append(test_conv)
conv_out = []
output = []
vis_output =[]

conv_out_bi = []
output_bi = []
vis_output_bi = []

# More Validation datas for Qualitative evaluation
val_list = open('/root/dataset-dllab/lab06/list/val.txt').readlines()

for i in range(img_num):
    x = cv2.imread(os.path.join('/root/dataset-dllab/lab06/img', val_list[i*9+230][:-1] + '.jpg')).astype(float)
    x[:, :, 0] -= 104.008
    x[:, :, 1] -= 116.669
    x[:, :, 2] -= 122.675
    x = torch.from_numpy(x.transpose((2,0,1))).float().cuda().unsqueeze(0)
    img.append(x.to(device))    


with torch.no_grad():    
    for i in range(len(img)):
        conv_out.append(model(img[i]))
        output.append( torch.argmax(conv_out[i],dim=1))
        vis_output.append(decode_labels(output[i][0].data.cpu().numpy()))
        conv_out_bi.append(conv_vgg_upsample(img[i]))
        output_bi.append( torch.argmax(conv_out_bi[i],dim=1))
        vis_output_bi.append(decode_labels(output_bi[i][0].data.cpu().numpy()))
                          
                          
fig, ax = plt.subplots(len(img),3,figsize = (15,20))
for i in range(len(img)):   
    ax[i,0].imshow(img[i][0].data.cpu().numpy().transpose((1,2,0)))
    #     ax[i,0].imshow(img[i])
    ax[i,1].imshow(vis_output[i])
    ax[i,2].imshow(vis_output_bi[i])

    ax[i,0].set_title('Image')
    ax[i,1].set_title('FCN8s')
    ax[i,2].set_title('VGG Bilinear Upsampled')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### *References*
# [1] FCN official code (https://github.com/shelhamer/fcn.berkeleyvision.org)
#
# [2] Upsampling method (https://towardsdatascience.com/types-of-convolutions-in-deep-learning-717013397f4d)
#
# [3] Cs231n (http://cs231n.stanford.edu/slides/2017/cs231n_2017_lecture11.pdf)
