# %% [markdown]
# > ### EEE4423: Deep Learning Lab
#
# # LAB #7: High-level Vision - Single Shot Object Detection (YOLO)

# %%
import datetime
print("This code is written at " + str(datetime.datetime.now()))
# Out:
# This code is written at 2023-04-17 04:27:54.163330

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torch.utils.data as data
from torch.autograd import Variable

import torchvision.datasets as dsets

import numpy as np
import cv2

import os
import struct
import copy
import random

import time
import datetime

import math

from PIL import Image
import torchvision.transforms as transforms
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils import data
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. What is the Object Detection?
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1pOo5As8Qo8bQOQjOkkpRwjVKcKNB4gSE" alt="no_image" style="width: 800px;"/>
# >
# > - The difference between $\bf{classification}$ (left) and $\bf{detection}$ (right) is simple
# >
# > - In image classification, the entire image is classified with a single label
# >
# > - In object detection, the network localizes (potentially multiple) objects within the image
# >
# > - Therefore, given the image, the obejct detection networks ouput a list of bounding box, class label, and **probability/confidence score**
# >
#
# ### 2. About YOLO (Main idea)
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1K7tvcGXdRHBc_t5p-m3uyRrCBFbJ9ze5" alt="no_image" style="width: 800px;"/>
# >
# > - YOLO is an algorithm for object detection
# >
# > - They reframe object detection as a $\bf{single\ regression\ problem}$, straight from image pixels to bounding box coordinates and class probabilities
# >
# > - Using YOLO, you only look once (YOLO) at an image to predict what objects are present and where they are
# >
# > - The advantage of YOLO is the speed, which is extremely fast, since the authors reframe detection as a regression problem not using a complex pipeline
# >
# > - What are differences between YOLO and previous detectors?? Refer to https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e

# %% [markdown]
# ### 3. Building a YOLO with PyTorch
#
# > ### YOLO model:
# > - 22Convolutional Layers
# >
# >     - Note that, first and 20th conv layers have stride 2 for halving output size
# >
# > - 4 Max Pooling Layers
# >
# > - 2 Fully Connected Layers
# >
# > - Leaky ReLu Activation for all layers except for the last layer
#
# ### 4. Implementing YOLO
# >
# > - The input image is divided into an S $\times$ S grid of cells
# >
# > - Each grid cell predicts B (=2) bounding boxes as well as C (=20) class probabilities
# >
# > - Each bounding box consists of 5 predictions: x, y, w, h, and confidence
# >
# > - The (x,y) coordinates represent the center of the box relative to the bounds of the grid cell
# >
# > - The width and height are predicted relative to the whole image
# >
# > - If no object exists in that cell, the confidence score is zero.
# >
# > - If the cell contains objects, the confidence score is equal to the intersection over union (IOU) between the predicted box and the ground truth (**This is important for building the loss function**)
# >
# > - Thus, the output vector is a S $\times$ S $\times$ (B $\times$ 5 + C) (= 7 $\times$ 7 $\times$ 30)
# >
# > <img src="https://drive.google.com/uc?export=view&id=1LdKtTyYjGKKWmu-4nTYBEMI7n4Sk0aeB" alt="no_image" style="width: 600px;"/>
# >
# > - You must study *generate_target* function in detail, it contains the process of generating output vectors
# >
# > Step 1: Load the dataset
# >
# > Step 2: Build the YOLO network ($\bf{4 points}$)
# >>
# >>  <img src="https://drive.google.com/uc?export=view&id=1c4yOWTZacei0_pFoI47wfxVEhM5Tms8X" alt="no_image" style="width: 800px;"/>
# >>
# >> - Following the YOLO model, you build yolo network
# >> - **Note that our model is different from network of original paper. Please follow above figure.**
# >> - You must fill out the blank in **self.pre_train_net** and **self.post_net** blocks
# >> - All layers use the following Leaky ReLU (0.01 slope for negative part - Note that it is different from the paper)
# >>
# >>
# >> #### **self.pre_train_net**
# >>
# >>
# >>
# >>| Name       | Filters              | Output Dimension | Padding |
# >>|------------|----------------------|------------------| ------- |
# >>| Conv 1     | 7 x 7 x 64, stride=2 | 224 x 224 x 64   | 3       |
# >>| LeakyReLU  | negative_slop=0.01   | 224 x 224 x 64   |         |
# >>| Max Pool 1 | 2 x 2, stride=2      | 112 x 112 x 64   |         |
# >>|
# >>| Conv 2     | 3 x 3 x 192          | 112 x 112 x 192  | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 112 x 112 x 192  |         |
# >>| Max Pool 2 | 2 x 2, stride=2      | 56 x 56 x 192    |         |
# >>|
# >>| Conv 3     | 1 x 1 x 128          | 56 x 56 x 128    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 128    |         |
# >>| Conv 4     | 3 x 3 x 256          | 56 x 56 x 256    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 256    |         |
# >>| Conv 5     | 1 x 1 x 256          | 56 x 56 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 256    |         |
# >>| Conv 6     | 3 x 3 x 512          | 56 x 56 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 512    |         |
# >>| Max Pool 3 | 2 x 2, stride=2      | 28 x 28 x 512    |         |
# >>|
# >>| Conv 7     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 8     | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 9     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 10    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 11    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 12    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 13    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 14    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 15    | 1 x 1 x 512          | 28 x 28 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 16    | 3 x 3 x 1024         | 28 x 28 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 1024   |         |
# >>| Max Pool 4 | 2 x 2, stride=2      | 14 x 14 x 1024   |         |
# >>|
# >>| Conv 17    | 1 x 1 x 512          | 14 x 14 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 14 x 14 x 512    |         |
# >>| Conv 18    | 3 x 3 x 1024         | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 14 x 14 x 1024   |         |
# >>
# >> #### **self.post_net**
# >>
# >>| Name      | Filters                | Output Dimension | Padding |
# >>|-----------|------------------------|------------------| ------- |
# >>| Conv 19   | 3 x 3 x 1024           | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 14 x 14 x 1024   |         |
# >>| Conv 20   | 3 x 3 x 1024, stride=2 | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 7 x 7 x 1024     |         |
# >>| Conv 21   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 7 x 7 x 1024     |         |
# >>| Conv 22   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 7 x 7 x 1024     |         |
# >>
# > Step 3: Loss function ($\bf{6 points}$)
# >
# >> - Fill out the code considering the loss function in YOLO
# >> - The loss function is composed like below
# >> <img src="https://drive.google.com/uc?export=view&id=1QcAP__J50M379GAul7SlhAzzU551tuDj" alt="no_image" style="width: 600px;"/>
# >>
# >> - $\mathbb{1}_{obj}$ is defined as follows:
# >>    - 1, if an object is present in grid cell $i$ and the $j$th bounding box predictor
# >>    - 0, otherwise
# >>
# >> - YOLO predicts multiple bounding boxes per grid cell (in our case, 2 bounding boxes are predicted)
# >> - In train stage, YOLO requires one bounding box predictor to be responsible for each object
# >> - The code assigns one predictor to be "responsible" for predicting an object where the predictor has the highest IOU with the ground truth
# >> - The loss function is divided into the three sub-sections
# >>    1. Classification ( $\bf{6}$ classes ) ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=13mnxg_GNtbWnYLpe1P6zopf693zTYe22" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Similar to sum-squared error for classification except for $\mathbb{1}_{obj}$ term
# >>
# >>       - Note that, we do not penalize classification error when no object is present on the cell (by $\mathbb{1}_{obj}$ term)
# >>
# >>    2. No object appears in cell ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1R74HzbRLoX2K5zun8XSLAnRQlKq25XFV" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Compute the loss associated with the confidence score for each bounding box predictor
# >>
# >>       - $\mathbb{1}_{noobj}$ is equal to one when there is no object in the cell, and 0 other wise
# >>    3. Bounding box coordinates (x,y,h,w) regression (4 scalars), and Object confidence ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1lXs5lHUiXGxgMRNCiViY6SyRDL52gQsy" alt="no_image" style="width: 600px;"/>
# >>
# >>       - Compute the loss realted to the predicted bounding box position $(x,y)$ and width/height $(w,h)$
# >>
# >>       - Note that width/height are adapted square root before computing the loss
# >>
# >>       - In order to solve the problem that small deviations in large boxes matter less than in small boxes
# >>
# >>       - Compute the loss associated with the confidence score for the cell which is responsible for the object
# >>
# >> - Following the paper, $\lambda_{coord} = 5$ and $\lambda_{noobj} = 0.5$
# >>
# > Step 4: Train Model ($\bf{2 points}$)
# >>
# >> - Based on the above code, you build train code on your own
# >> - The necessary things are provided (e.g., *optimizer* and *num_epoch*)
# >> - Note that, we offer the pre-trained model since it requires large training time.
# >> - If you construct your code correctly, the performance of mAP will be over 0.69 mAP in 10 epochs (about 15 minitues.)
# >>
# > Step 5: Inference
# >>
# >> - We offer the test code in below
# >> - You can check the qualitative results using the visualization code
# >> - The quantitative results will be evaluated by using the mAP code
# >> - If the performance of mAP is significantly decreased from the pre-trained model (0.685 mAP), your code will be wrong
# >>
# >> Step 5-1: Inference (Visualization)
# >>
# >> Step 5-2: Inference (mAP)

# %% [markdown]
# ### Step 1. Load the dataset

# %%
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"

class YoloDataset(data.Dataset):
    def __init__(self, root, list_file, train, transform=None):
        self.image_size = 448
        self.root = root
        self.train = train
        self.transform = transform
        self.fnames = []
        self.boxes = []
        self.labels = []
        self.color_jitter = Compose([transforms.ColorJitter(brightness=0.1,contrast=0.1, saturation=0.1, hue=0.1),
                                                 transforms.ToTensor()])
        self.plain = Compose([transforms.ToTensor()])
        self.resize = Compose([transforms.ToPILImage(),
                              transforms.Resize((self.image_size, self.image_size)),
                              transforms.ToTensor()])
        
        with open(list_file) as f:
            lines = f.readlines()
            
        for line in lines:
            splited = line.strip().split()
            self.fnames.append(splited[0])
            num_boxes = (len(splited) - 1) // 5
            box = []
            label = []
            for i in range(num_boxes):
                x_min = float(splited[1+5*i])
                y_min = float(splited[2+5*i])
                x_max = float(splited[3+5*i])
                y_max = float(splited[4+5*i])
                c = splited[5+5*i]
                box.append([x_min, y_min, x_max, y_max])
                label.append(int(c)+1)
            self.boxes.append(torch.Tensor(box))
            self.labels.append(torch.LongTensor(label))
        self.num_samples = len(self.boxes)
        
    def img_pre_process(self, img, boxes, labels):
        
        if random.random() < 0.5:
            im_lr = np.fliplr(img).copy()
            height, width, c = img.shape
            x_min = width - boxes[:, 2]
            x_max = width - boxes[:, 0]
            boxes[:,0] = x_min
            boxes[:,2] = x_max
            img = im_lr
        
        ## Converting the image and box information scaling
        if random.random() < 0.5:
            scale = random.uniform(0.8, 1.2)
            height, width, c = img.shape
            img = cv2.resize(img, (int(width * scale), height))
            boxes = boxes * torch.FloatTensor([[scale, 1, scale, 1]]).expand_as(boxes)
            
        ## Image translation
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            shifted_img = np.zeros((height, width, c), dtype=img.dtype)
            
            w_range = int(random.uniform(-width*0.2, width*0.2))
            h_range = int(random.uniform(-height*0.2, height*0.2))
            
            if w_range<0 and h_range<0:
                shifted_img[:height+h_range,:width+w_range,:] = img[-h_range:,-w_range:,:]
                
            elif w_range<0 and h_range>=0:
                shifted_img[h_range:,:width+w_range,:] = img[:height-h_range,-w_range:,:]
            
            elif w_range>=0 and h_range>=0:
                shifted_img[h_range:,w_range:,:] = img[:height-h_range,:width-w_range,:]
                
            elif w_range>=0 and h_range<0:
                shifted_img[:height+h_range,w_range:,:] = img[-h_range:,:width-w_range,:]
                
            wh_range = torch.FloatTensor([[w_range, h_range]]).expand_as(center)
            center = center + wh_range
            
            mask1 = (center[:,0] > 0) & (center[:,0] < width)
            mask2 = (center[:,1] > 0) & (center[:,1] < height)
            mask = (mask1 & mask2).view(-1,1).bool()
            
            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)
            
            if len(boxes_in) != 0:
                box_shift = torch.FloatTensor([[w_range, h_range, w_range, h_range]]).expand_as(boxes_in)
                boxes_in = boxes_in + box_shift
                
                labels_in = labels[mask.view(-1)]
                labels = labels_in
                img = shifted_img
                boxes = boxes_in
        
        ## Image cropping
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            h = int(random.uniform(0.6*height,height))
            w = int(random.uniform(0.6*width,width))
            x = int(random.uniform(0,width-w))
            y = int(random.uniform(0,height-h))
            
            center = center - torch.FloatTensor([[x, y]]).expand_as(center)
            mask1 = (center[:,0]>0) & (center[:,0]<w)
            mask2 = (center[:,1]>0) & (center[:,1]<h)
            mask = (mask1 & mask2).view(-1, 1).bool()
            
            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)
            
            if (len(boxes_in)!=0):
                box_shift = torch.FloatTensor([x,y,x,y]).expand_as(boxes_in)

                boxes_in = boxes_in - box_shift
                boxes_in[:,0]=boxes_in[:,0].clamp_(min=0,max=w)
                boxes_in[:,2]=boxes_in[:,2].clamp_(min=0,max=w)
                boxes_in[:,1]=boxes_in[:,1].clamp_(min=0,max=h)
                boxes_in[:,3]=boxes_in[:,3].clamp_(min=0,max=h)

                labels = labels[mask.view(-1)]
                img_cropped = img[y:y+h, x:x+w, :]
                boxes = boxes_in
                img = img_cropped
        
        return img, boxes, labels

    def generate_target(self, img, boxes, labels):
        grid_size = 7
        h,w,_ = img.shape
        boxes /= torch.Tensor([w,h,w,h]).expand_as(boxes) # Converting the box size 0 ~ 1
        target = torch.zeros((grid_size, grid_size, 30)) 
        cell_size = 1./grid_size 

        wh = boxes[:,2:] - boxes[:,:2]
        cxcy = (boxes[:,2:] + boxes[:,:2]) / 2
        
        for i in range(cxcy.size()[0]):
            cxcy_sample = cxcy[i] # center pixel 
            ij = (cxcy_sample/cell_size).ceil()-1 
            target[int(ij[1]),int(ij[0]),4] = 1
            target[int(ij[1]),int(ij[0]),9] = 1
            target[int(ij[1]),int(ij[0]),int(labels[i])+9] = 1
            
            xy = ij*cell_size 
            delta_xy = (cxcy_sample -xy)/cell_size # Converting delta_xy to the size 
                                                   # relative to the bounds of the grid cell
            target[int(ij[1]),int(ij[0]),2:4] = wh[i]
            target[int(ij[1]),int(ij[0]),:2] = delta_xy
            target[int(ij[1]),int(ij[0]),7:9] = wh[i]
            target[int(ij[1]),int(ij[0]),5:7] = delta_xy
            
        return target
    
    def RandomBrightness(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            v = v*adjust
            v = np.clip(v, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomSaturation(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            s = s*adjust
            s = np.clip(s, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomHue(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            h = h*adjust
            h = np.clip(h, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr

    def randomBlur(self,bgr):
        if random.random()<0.5:
            bgr = cv2.blur(bgr,(5,5))
        return bgr
        
    def __getitem__(self, idx):
        fname = self.fnames[idx]
        img = cv2.imread(os.path.join(self.root+fname))
        boxes = self.boxes[idx].clone()
        labels = self.labels[idx].clone()

        if self.train:
            img = self.randomBlur(img)
            img = self.RandomBrightness(img)
            img = self.RandomHue(img)
            img = self.RandomSaturation(img)
            img, boxes, labels = self.img_pre_process(img, boxes, labels)
            
        target = self.generate_target(img, boxes, labels) # 7x7x30
        
        # Image processing
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        img = self.plain(img)
        img = self.resize(img)
        img = 2 * img - 1
        
        return img, target
    
    def __len__(self):
        return self.num_samples

# %% [markdown]
# ### Step 2. Build the YOLO network (2 points)

# %% [markdown]
# > You should build model using nn.Sequential. Otherwise, problem arises when loading pretrained weights.

# %%
class YOLO(nn.Module):
    def __init__(self):
        super(YOLO, self).__init__()
        
        # i/2 = (i-k+2p)/s +1 = (i-7 + 2 *(p = 3))/2 + 1
        self.pre_train_net = nn.Sequential(
            ################
            ### Fill out ###
            ################
            #conv1
            nn.Conv2d(3,64,7,2,3),
            nn.LeakyReLU(),
            nn.MaxPool2d(2,2),
            # conv2
            nn.Conv2d(64,192,3,1,1),
            nn.LeakyReLU(),
            nn.MaxPool2d(2,2),
            # conv3
            nn.Conv2d(192,128,1,1),
            nn.LeakyReLU(),
            # conv4
            nn.Conv2d(128,256,3,1,1),
            nn.LeakyReLU(),
            # conv5
            nn.Conv2d(256,256,1,1),
            nn.LeakyReLU(),
            # conv6
            nn.Conv2d(256,512,3,1,1),
            nn.LeakyReLU(),
            nn.MaxPool2d(2,2),
            # conv7
            nn.Conv2d(512,256,1,1),
            nn.LeakyReLU(),
            # conv8
            nn.Conv2d(256,512,3,1,1),
            nn.LeakyReLU(),
            # conv9
            nn.Conv2d(512,256,1,1),
            nn.LeakyReLU(),
            # conv10
            nn.Conv2d(256,512,3,1,1),
            nn.LeakyReLU(),
            # conv11
            nn.Conv2d(512,256,1,1),
            nn.LeakyReLU(),
            # conv12
            nn.Conv2d(256,512,3,1,1),
            nn.LeakyReLU(),
            # conv13
            nn.Conv2d(512,256,1,1),
            nn.LeakyReLU(),
            # conv14
            nn.Conv2d(256,512,3,1,1),
            nn.LeakyReLU(),
            # conv15
            nn.Conv2d(512,512,1,1),
            nn.LeakyReLU(),
            # conv16
            nn.Conv2d(512,1024,3,1,1),
            nn.LeakyReLU(),
            nn.MaxPool2d(2,2),
            # conv17
            nn.Conv2d(1024,512,1,1),
            nn.LeakyReLU(),
            # conv18
            nn.Conv2d(512,1024,3,1,1),
            nn.LeakyReLU()          
            
        )
        
        self.post_net = nn.Sequential(
            ################
            ### Fill out ###
            ################
            # conv19
            nn.Conv2d(1024,1024,3,1,1),
            nn.LeakyReLU(),
            # conv20
            nn.Conv2d(1024,1024,3,2,1),
            nn.LeakyReLU(),
            # conv21
            nn.Conv2d(1024,1024,3,1,1),
            nn.LeakyReLU(),
            # conv22
            nn.Conv2d(1024,1024,3,1,1),
            nn.LeakyReLU()            
        )
        
        self.FC1 = nn.Sequential(
            nn.Linear(50176, 4096),
            nn.LeakyReLU(),
            nn.Dropout()
        )
        
        self.FC2 = nn.Sequential(
            nn.Linear(4096, 1470)
        )
        
        self.pre_train_net.cuda()
        self.post_net.cuda()
        self.FC1.cuda()
        self.FC2.cuda()
        
        self._initialize_weights()

    def forward(self, x):
        output = self.pre_train_net(x)
        output = self.post_net(output)

        # Ready to going for FC layer
        output = output.view(output.size(0), -1)

        output = self.FC1(output)
        output = self.FC2(output)

        output = output.view(output.size(0), 7, 7, 30)
        # Converting the output shape to the (batch_size, 7, 7, 30)
        output = F.relu(output)

        return output
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()

# %% [markdown]
# ### Step 3. Loss function (6 points)

# %%
class yoloLoss(nn.Module):
    def __init__(self,l_coord,l_noobj):
        super(yoloLoss,self).__init__()
        self.l_coord = l_coord
        self.l_noobj = l_noobj
    
    def compute_prob_error(self, pred, target): ## classification error
        # Confidence layer(ground_truth = 1) -> finding the responsible predictor?
        # -> Expand(x30) with actual prediction index!
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1] 
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        
        ################
        ### Fill out ###
        ################
        
        contain_pred = pred[contain].contiguous().view(-1,30) # Only cell which contains the object are remained
        prob_pred = contain_pred[:,10:] # just class info
        
        contain_target = target[contain].contiguous().view(-1,30)
        prob_target = contain_target[:,10:] # just class info
        # 1. also MSE for class... but why not cross-entropy?
#         2. only 6 classes are used among 20 classes... but just do it?
        prob_loss = F.mse_loss(prob_pred,prob_target, size_average = False)
        
        
        return prob_loss
    
    def not_contain_obj_error(self, pred, target): ## Error where no object appears in cell
        not_contain = target[:,:,:,4] == 0 # [Batch_size, 7, 7, 1]
        not_contain = not_contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        
        ################
        ### Fill out ###
        ################
        # Confidnece value of predictors from the grid cell which does not contain object!

        not_contain_pred = pred[not_contain].contiguous().view(-1,30) # Only cell which does not contains the object are remained
        not_contain_box_pred = not_contain_pred[:,:10].contiguous().view(-1,5)[:,4] # Reshaping, just confidence info
        
        not_contain_target = target[not_contain].contiguous().view(-1,30)
        not_contain_box_target = not_contain_target[:,:10].contiguous().view(-1,5)[:,4] # just confidence info
        
        noobj_loss1 = F.mse_loss(not_contain_box_pred, not_contain_box_target, size_average=False)
        
        return noobj_loss1
    
    
    def contain_obj_error(self, pred, target): ##
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        
        # Q. 왜 target에서의 predictor로 grid index? whynot pred[:,:,:,4]>0
        # A. 애초에 Grid cell의 position에 맞는 predictor가 ground truth!
        # -> ground truth predictor의 grid cell에서의  predictor만 보면 된다
        contain_pred = pred[contain].contiguous().view(-1,30) # Only cell which contains the object are remained
        box_pred = contain_pred[:,:10].contiguous().view(-1,5) # Reshaping
        
        contain_target = target[contain].contiguous().view(-1,30)
        box_target = contain_target[:,:10].contiguous().view(-1,5) # just box + confidence info
        
        # Note that, We assign one predictor to be "responsible" for predicting 
        # an object based on which prediction has the highest current IOU with the ground truth
        # Then, other prediction is "not responsible" for predicting an object
        # That component is included in "contain_noobj_mask variables
        
        # [num of pred, 5] among total batch
        contain_obj_mask = torch.cuda.ByteTensor(box_target.size()).zero_().bool() # Create the mask
        contain_noobj_mask = torch.cuda.ByteTensor(box_target.size()).zero_().bool() 
        
        target_iou_gt = torch.zeros(box_target[:,0].size()).cuda() # In order to save the IoU for confidence 
                                                                   # of the cell which contains object
        # Assigning responsible predictor
        for i in range(0, box_target.size()[0], 2): # range(0, 26 predictors, 2)
            box_p = box_pred[i:i+2] # For 2 bounding boxes information from same cell!
            box_p_coord = Variable(torch.FloatTensor(box_p.size())) # Box coordinate (x_min, y_min, x_max, y_max)
            box_p_coord[:,:2] = box_p[:,:2] - box_p[:,2:4]/2 
            box_p_coord[:,2:4] = box_p[:,:2] + box_p[:,2:4]/2

            box_t = box_target[i].contiguous().view(-1,5) # target은 cell하나당 같은 prediction box? 왜 하나만?
            box_t_coord = Variable(torch.FloatTensor(box_t.size()))
            box_t_coord[:,:2] = box_t[:,:2] - box_t[:,2:4]/2 
            box_t_coord[:,2:4] = box_t[:,:2] + box_t[:,2:4]/2
            
            iou = self.compute_iou(box_p_coord[:,:4], box_t_coord[:,:4]) # [2,]
                                                      # compute IoU between prediction and target boxes, 
            
            gt_iou, max_idx = iou.max(0) # Choose predictor among 2 boxes of the grid cell
            contain_obj_mask[i+max_idx] = 1
            contain_noobj_mask[i+1-max_idx] = 1
            
            target_iou_gt[i+max_idx] = gt_iou.data.cuda()
            
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        target_iou_gt = target_iou_gt.to(device)
        
        ## For the cell which contains object
        contain_box_pred = box_pred[contain_obj_mask].view(-1,5) ## Fill out 
        
        ## For the cell which does not contain object
        not_contain_box_pred = box_pred[contain_noobj_mask].view(-1,5) ## Fill out 

        ## For target domain 
        contain_box_target = box_target[contain_obj_mask].view(-1,5) ## Fill out
        not_contain_box_target = box_target[contain_noobj_mask].view(-1,5) ## Fill out
#         print(contain_obj_mask.shape,box_target.shape, contain_box_target.shape,not_contain_box_target.shape)
        not_contain_box_target[:,4] = 0 # 0 confidence
        
        ## For the GT IoU 
        
#         print(contain_obj_mask.shape, target_iou_gt.shape)
        contain_iou_target = target_iou_gt[contain_obj_mask[:,4]] ## Fill out 
        
        obj_loss = F.mse_loss(contain_box_pred[:,4], contain_iou_target, size_average=False)
        xy_loss = F.mse_loss(contain_box_pred[:,:2], contain_box_target[:,:2], size_average=False)
        wh_loss = F.mse_loss(torch.sqrt(contain_box_pred[:,2:4]), torch.sqrt(contain_box_target[:,2:4]), size_average=False)
        # this noobj loss is for the predictor that it's cell contains object, but not the assigned predictor
        noobj_loss2 = F.mse_loss(not_contain_box_pred[:,4], not_contain_box_target[:,4], size_average=False)
        
        return obj_loss, xy_loss, wh_loss, noobj_loss2
        
    def compute_iou(self, box_p, box_t):
        
        pred_area = (box_p[:,2] - box_p[:,0]) * (box_p[:,3] - box_p[:,1]) # [2,]
        target_area = (box_t[:,2] - box_t[:,0]) * (box_t[:,3] - box_t[:,1]) #[1,]
        
        box_p = box_p.unsqueeze(1).expand(2,1,4)
        box_t = box_t.unsqueeze(0).expand(2,1,4)
        
        inter_lt = torch.max(box_p[:,:,:2], box_t[:,:,:2]) # [2,1,2]
        
        inter_rb = torch.min(box_p[:,:,2:], box_t[:,:,2:]) # [2,1,2]
        
        wh = inter_rb - inter_lt # [2,1,2]
        wh[wh<0] = 0 
        
        inter_area = wh[:,:,0] * wh[:,:,1] # [2,1]
        pred_area = pred_area.unsqueeze(1).expand_as(inter_area)
        target_area = target_area.unsqueeze(0).expand_as(inter_area)
        
        iou = inter_area / (pred_area + target_area - inter_area)
        
        return iou
    
        
    
    def forward(self,pred,target):

        batch_size = pred.size()[0]
        
        noobj_loss1 = self.not_contain_obj_error(pred, target)
        prob_loss = self.compute_prob_error(pred, target)
        obj_loss, xy_loss, wh_loss, noobj_loss2 = self.contain_obj_error(pred, target)
        
        total_loss = (self.l_coord*(xy_loss + wh_loss) + obj_loss + self.l_noobj*(noobj_loss1 + noobj_loss2) + prob_loss)
        
        return total_loss / batch_size

# %% [markdown]
# ### Step 4. Train the model

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
file_root = '/root/dataset-dllab/lab07/all_img/'
train_dataset = YoloDataset(root=file_root, list_file='/root/misc/lab07/Generate_dataset/voc2007+2012.txt', train=True)
train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True, num_workers=4)

model = YOLO()
state_dict = torch.load('/root/pretrain/lab07/pre_train.pt')
model.load_state_dict(state_dict['state_dict'])
print('pre_train_complete')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

learning_rate = 1e-4
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
optimizer.load_state_dict(state_dict['optimizer'])

criterion = yoloLoss(l_coord=5,l_noobj=0.5)

best = 1e+30
num_epochs = 15
print("training start!")

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
        
    for i, (images, target) in enumerate(train_loader):
        images = images.to(device)
        target = target.to(device)
        
        pred = model(images)
        loss = criterion(pred, target)
        
        total_loss += loss.item()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 10 == 0:
            print('Epoch [%d/%d], Iter [%d,%d] Loss:%.4f, average_loss: %.4f' % (epoch+1, num_epochs, i+1, len(train_loader), loss.item(), total_loss / (i+1)))
# Out:
# pre_train_complete
# training start!
# Epoch [1/15], Iter [10,430] Loss:0.3519, average_loss: 0.6637
# Epoch [1/15], Iter [20,430] Loss:0.2223, average_loss: 0.6646
# Epoch [1/15], Iter [30,430] Loss:0.6725, average_loss: 0.6680
# Epoch [1/15], Iter [40,430] Loss:1.1907, average_loss: 0.6694
# Epoch [1/15], Iter [50,430] Loss:0.3562, average_loss: 0.6526
# Epoch [1/15], Iter [60,430] Loss:0.3645, average_loss: 0.6454
# Epoch [1/15], Iter [70,430] Loss:0.4721, average_loss: 0.6680
# Epoch [1/15], Iter [80,430] Loss:0.6999, average_loss: 0.6618
# Epoch [1/15], Iter [90,430] Loss:0.8449, average_loss: 0.6523
# Epoch [1/15], Iter [100,430] Loss:0.2933, average_loss: 0.6363
# Epoch [1/15], Iter [110,430] Loss:0.6642, average_loss: 0.6333
# Epoch [1/15], Iter [120,430] Loss:0.6560, average_loss: 0.6285
# Epoch [1/15], Iter [130,430] Loss:0.7559, average_loss: 0.6286
# Epoch [1/15], Iter [140,430] Loss:0.8130, average_loss: 0.6405
# Epoch [1/15], Iter [150,430] Loss:0.5503, average_loss: 0.6356
# Epoch [1/15], Iter [160,430] Loss:1.3975, average_loss: 0.6376
# Epoch [1/15], Iter [170,430] Loss:0.4206, average_loss: 0.6382
# Epoch [1/15], Iter [180,430] Loss:0.4401, average_loss: 0.6286
# Epoch [1/15], Iter [190,430] Loss:0.4027, average_loss: 0.6227
# Epoch [1/15], Iter [200,430] Loss:0.4761, average_loss: 0.6151
# Epoch [1/15], Iter [210,430] Loss:0.9148, average_loss: 0.6107
# Epoch [1/15], Iter [220,430] Loss:0.3167, average_loss: 0.6045
# Epoch [1/15], Iter [230,430] Loss:0.9289, average_loss: 0.6021
# Epoch [1/15], Iter [240,430] Loss:0.5185, average_loss: 0.5972
# Epoch [1/15], Iter [250,430] Loss:0.6145, average_loss: 0.5988
# Epoch [1/15], Iter [260,430] Loss:0.4841, average_loss: 0.5988
# Epoch [1/15], Iter [270,430] Loss:0.2990, average_loss: 0.5968
# Epoch [1/15], Iter [280,430] Loss:1.5010, average_loss: 0.5948
# Epoch [1/15], Iter [290,430] Loss:0.5676, average_loss: 0.5935
# Epoch [1/15], Iter [300,430] Loss:0.8819, average_loss: 0.5959
# Epoch [1/15], Iter [310,430] Loss:0.4851, average_loss: 0.5970
# Epoch [1/15], Iter [320,430] Loss:0.7030, average_loss: 0.5980
# Epoch [1/15], Iter [330,430] Loss:0.8033, average_loss: 0.5988
# Epoch [1/15], Iter [340,430] Loss:0.3624, average_loss: 0.5980
# Epoch [1/15], Iter [350,430] Loss:0.4710, average_loss: 0.5964
# Epoch [1/15], Iter [360,430] Loss:0.4656, average_loss: 0.5943
# Epoch [1/15], Iter [370,430] Loss:0.4304, average_loss: 0.5943
# Epoch [1/15], Iter [380,430] Loss:0.9800, average_loss: 0.5952
# Epoch [1/15], Iter [390,430] Loss:0.9639, average_loss: 0.5969
# Epoch [1/15], Iter [400,430] Loss:0.4641, average_loss: 0.6004
# Epoch [1/15], Iter [410,430] Loss:1.1233, average_loss: 0.6011
# Epoch [1/15], Iter [420,430] Loss:0.7326, average_loss: 0.6006
# Epoch [1/15], Iter [430,430] Loss:0.5016, average_loss: 0.5971
# Epoch [2/15], Iter [10,430] Loss:0.4299, average_loss: 0.4978
# Epoch [2/15], Iter [20,430] Loss:0.4550, average_loss: 0.5024
# Epoch [2/15], Iter [30,430] Loss:0.5174, average_loss: 0.6043
# Epoch [2/15], Iter [40,430] Loss:0.6410, average_loss: 0.5854
# Epoch [3/15], Iter [30,430] Loss:0.4736, average_loss: 0.4831
# Epoch [3/15], Iter [40,430] Loss:0.5034, average_loss: 0.4858
# Epoch [3/15], Iter [50,430] Loss:0.3545, average_loss: 0.4880
# Epoch [3/15], Iter [60,430] Loss:0.4348, average_loss: 0.4829
# Epoch [3/15], Iter [70,430] Loss:0.5817, average_loss: 0.4913
# Epoch [3/15], Iter [80,430] Loss:0.3733, average_loss: 0.4939
# Epoch [3/15], Iter [90,430] Loss:0.2863, average_loss: 0.4891
# Epoch [3/15], Iter [100,430] Loss:0.6905, average_loss: 0.4986
# Epoch [3/15], Iter [110,430] Loss:0.7494, average_loss: 0.5095
# Epoch [3/15], Iter [120,430] Loss:0.4779, average_loss: 0.5197
# Epoch [3/15], Iter [130,430] Loss:0.3391, average_loss: 0.5253
# Epoch [3/15], Iter [140,430] Loss:0.6570, average_loss: 0.5218
# Epoch [3/15], Iter [150,430] Loss:0.4119, average_loss: 0.5181
# Epoch [3/15], Iter [160,430] Loss:0.2691, average_loss: 0.5239
# Epoch [3/15], Iter [170,430] Loss:0.8214, average_loss: 0.5271
# Epoch [3/15], Iter [180,430] Loss:0.7875, average_loss: 0.5293
# Epoch [3/15], Iter [190,430] Loss:1.2427, average_loss: 0.5370
# Epoch [3/15], Iter [200,430] Loss:0.4309, average_loss: 0.5402
# Epoch [3/15], Iter [210,430] Loss:0.6956, average_loss: 0.5407
# Epoch [3/15], Iter [220,430] Loss:0.5236, average_loss: 0.5428
# Epoch [3/15], Iter [230,430] Loss:0.3769, average_loss: 0.5377
# Epoch [3/15], Iter [240,430] Loss:0.7190, average_loss: 0.5368
# Epoch [3/15], Iter [250,430] Loss:1.4260, average_loss: 0.5415
# Epoch [3/15], Iter [260,430] Loss:0.3644, average_loss: 0.5403
# Epoch [3/15], Iter [270,430] Loss:0.7011, average_loss: 0.5380
# Epoch [3/15], Iter [280,430] Loss:0.5613, average_loss: 0.5388
# Epoch [3/15], Iter [290,430] Loss:0.3484, average_loss: 0.5349
# Epoch [3/15], Iter [300,430] Loss:0.4044, average_loss: 0.5354
# Epoch [3/15], Iter [310,430] Loss:0.3969, average_loss: 0.5365
# Epoch [3/15], Iter [320,430] Loss:0.4947, average_loss: 0.5360
# Epoch [3/15], Iter [330,430] Loss:0.3469, average_loss: 0.5387
# Epoch [3/15], Iter [340,430] Loss:0.3906, average_loss: 0.5385
# Epoch [3/15], Iter [350,430] Loss:0.5846, average_loss: 0.5361
# Epoch [3/15], Iter [360,430] Loss:0.9592, average_loss: 0.5385
# Epoch [3/15], Iter [370,430] Loss:0.8630, average_loss: 0.5382
# Epoch [3/15], Iter [380,430] Loss:0.3391, average_loss: 0.5366
# Epoch [3/15], Iter [390,430] Loss:0.7811, average_loss: 0.5385
# Epoch [3/15], Iter [400,430] Loss:0.3749, average_loss: 0.5386
# Epoch [3/15], Iter [410,430] Loss:0.5930, average_loss: 0.5398
# Epoch [3/15], Iter [420,430] Loss:0.7674, average_loss: 0.5399
# Epoch [4/15], Iter [410,430] Loss:0.5093, average_loss: 0.5426
# Epoch [4/15], Iter [420,430] Loss:0.8445, average_loss: 0.5463
# Epoch [4/15], Iter [430,430] Loss:0.2933, average_loss: 0.5474
# Epoch [5/15], Iter [10,430] Loss:0.7066, average_loss: 0.6618
# Epoch [5/15], Iter [20,430] Loss:0.2875, average_loss: 0.6085
# Epoch [5/15], Iter [30,430] Loss:0.4502, average_loss: 0.5481
# Epoch [5/15], Iter [40,430] Loss:0.3403, average_loss: 0.5440
# Epoch [5/15], Iter [50,430] Loss:0.5654, average_loss: 0.5277
# Epoch [5/15], Iter [60,430] Loss:0.4660, average_loss: 0.5338
# Epoch [5/15], Iter [70,430] Loss:0.6300, average_loss: 0.5353
# Epoch [5/15], Iter [80,430] Loss:0.4616, average_loss: 0.5268
# Epoch [5/15], Iter [90,430] Loss:0.7506, average_loss: 0.5273
# Epoch [5/15], Iter [100,430] Loss:0.3262, average_loss: 0.5133
# Epoch [5/15], Iter [110,430] Loss:0.8607, average_loss: 0.5276
# Epoch [5/15], Iter [120,430] Loss:0.8925, average_loss: 0.5319
# Epoch [5/15], Iter [130,430] Loss:0.8500, average_loss: 0.5288
# Epoch [5/15], Iter [140,430] Loss:0.9833, average_loss: 0.5256
# Epoch [5/15], Iter [150,430] Loss:0.8299, average_loss: 0.5246
# Epoch [5/15], Iter [160,430] Loss:0.5439, average_loss: 0.5315
# Epoch [5/15], Iter [170,430] Loss:0.1980, average_loss: 0.5245
# Epoch [5/15], Iter [180,430] Loss:1.1681, average_loss: 0.5296
# Epoch [5/15], Iter [190,430] Loss:0.3773, average_loss: 0.5278
# Epoch [5/15], Iter [200,430] Loss:0.9312, average_loss: 0.5278
# Epoch [5/15], Iter [210,430] Loss:0.5066, average_loss: 0.5242
# Epoch [5/15], Iter [220,430] Loss:0.6013, average_loss: 0.5255
# Epoch [5/15], Iter [230,430] Loss:0.5379, average_loss: 0.5225
# Epoch [5/15], Iter [240,430] Loss:0.7341, average_loss: 0.5241
# Epoch [5/15], Iter [250,430] Loss:0.4797, average_loss: 0.5254
# Epoch [5/15], Iter [260,430] Loss:0.2536, average_loss: 0.5232
# Epoch [5/15], Iter [270,430] Loss:0.7391, average_loss: 0.5243
# Epoch [5/15], Iter [280,430] Loss:0.5540, average_loss: 0.5271
# Epoch [5/15], Iter [290,430] Loss:0.6019, average_loss: 0.5268
# Epoch [5/15], Iter [300,430] Loss:0.3372, average_loss: 0.5259
# Epoch [5/15], Iter [310,430] Loss:0.2556, average_loss: 0.5254
# Epoch [5/15], Iter [320,430] Loss:0.4179, average_loss: 0.5223
# Epoch [5/15], Iter [330,430] Loss:0.3440, average_loss: 0.5246
# Epoch [5/15], Iter [340,430] Loss:0.5565, average_loss: 0.5323
# Epoch [5/15], Iter [350,430] Loss:0.3903, average_loss: 0.5311
# Epoch [5/15], Iter [360,430] Loss:0.6218, average_loss: 0.5340
# Epoch [5/15], Iter [370,430] Loss:1.3101, average_loss: 0.5388
# Epoch [7/15], Iter [330,430] Loss:0.4024, average_loss: 0.5451
# Epoch [7/15], Iter [340,430] Loss:0.5193, average_loss: 0.5448
# Epoch [7/15], Iter [350,430] Loss:0.7907, average_loss: 0.5430
# Epoch [7/15], Iter [360,430] Loss:0.5103, average_loss: 0.5421
# Epoch [7/15], Iter [370,430] Loss:0.4178, average_loss: 0.5428
# Epoch [7/15], Iter [380,430] Loss:0.7951, average_loss: 0.5438
# Epoch [7/15], Iter [390,430] Loss:0.3493, average_loss: 0.5434
# Epoch [7/15], Iter [400,430] Loss:0.4356, average_loss: 0.5425
# Epoch [7/15], Iter [410,430] Loss:0.3804, average_loss: 0.5414
# Epoch [7/15], Iter [420,430] Loss:0.2980, average_loss: 0.5407
# Epoch [7/15], Iter [430,430] Loss:0.3644, average_loss: 0.5422
# Epoch [8/15], Iter [10,430] Loss:0.4170, average_loss: 0.5168
# Epoch [8/15], Iter [20,430] Loss:0.3746, average_loss: 0.5832
# Epoch [8/15], Iter [30,430] Loss:0.3487, average_loss: 0.5457
# Epoch [8/15], Iter [40,430] Loss:0.2710, average_loss: 0.5196
# Epoch [8/15], Iter [50,430] Loss:0.7736, average_loss: 0.5196
# Epoch [8/15], Iter [60,430] Loss:0.5048, average_loss: 0.5163
# Epoch [8/15], Iter [70,430] Loss:0.4044, average_loss: 0.5189
# Epoch [8/15], Iter [80,430] Loss:0.2741, average_loss: 0.5090
# Epoch [8/15], Iter [90,430] Loss:0.4088, average_loss: 0.5041
# Epoch [8/15], Iter [100,430] Loss:0.3107, average_loss: 0.4929
# Epoch [8/15], Iter [110,430] Loss:0.4654, average_loss: 0.5041
# Epoch [8/15], Iter [120,430] Loss:0.3826, average_loss: 0.5048
# Epoch [8/15], Iter [130,430] Loss:0.8004, average_loss: 0.5155
# Epoch [8/15], Iter [140,430] Loss:0.7516, average_loss: 0.5262
# Epoch [8/15], Iter [150,430] Loss:0.4714, average_loss: 0.5376
# Epoch [8/15], Iter [160,430] Loss:0.6284, average_loss: 0.5374
# Epoch [8/15], Iter [170,430] Loss:0.4410, average_loss: 0.5335
# Epoch [8/15], Iter [180,430] Loss:0.7608, average_loss: 0.5368
# Epoch [8/15], Iter [190,430] Loss:0.4564, average_loss: 0.5327
# Epoch [8/15], Iter [200,430] Loss:0.4312, average_loss: 0.5321
# Epoch [8/15], Iter [210,430] Loss:0.8305, average_loss: 0.5348
# Epoch [8/15], Iter [220,430] Loss:0.4811, average_loss: 0.5368
# Epoch [8/15], Iter [230,430] Loss:0.9107, average_loss: 0.5382
# Epoch [8/15], Iter [240,430] Loss:0.4192, average_loss: 0.5385
# Epoch [8/15], Iter [250,430] Loss:0.4266, average_loss: 0.5412
# Epoch [8/15], Iter [260,430] Loss:0.3394, average_loss: 0.5414
# Epoch [8/15], Iter [270,430] Loss:0.6464, average_loss: 0.5406
# Epoch [8/15], Iter [280,430] Loss:0.5165, average_loss: 0.5414
# Epoch [8/15], Iter [290,430] Loss:0.2620, average_loss: 0.5433
# Epoch [8/15], Iter [300,430] Loss:1.1021, average_loss: 0.5427
# Epoch [8/15], Iter [310,430] Loss:0.2690, average_loss: 0.5410
# Epoch [8/15], Iter [320,430] Loss:0.4666, average_loss: 0.5403
# Epoch [8/15], Iter [330,430] Loss:0.6186, average_loss: 0.5427
# Epoch [8/15], Iter [340,430] Loss:0.4441, average_loss: 0.5432
# Epoch [8/15], Iter [350,430] Loss:0.6596, average_loss: 0.5435
# Epoch [8/15], Iter [360,430] Loss:0.8984, average_loss: 0.5420
# Epoch [8/15], Iter [370,430] Loss:0.4083, average_loss: 0.5399
# Epoch [8/15], Iter [380,430] Loss:0.3473, average_loss: 0.5358
# Epoch [8/15], Iter [390,430] Loss:0.9898, average_loss: 0.5371
# Epoch [8/15], Iter [400,430] Loss:0.6297, average_loss: 0.5367
# Epoch [8/15], Iter [410,430] Loss:0.5253, average_loss: 0.5349
# Epoch [8/15], Iter [420,430] Loss:0.5197, average_loss: 0.5363
# Epoch [8/15], Iter [430,430] Loss:0.3441, average_loss: 0.5352
# Epoch [9/15], Iter [10,430] Loss:0.4703, average_loss: 0.5147
# Epoch [9/15], Iter [20,430] Loss:0.6055, average_loss: 0.4953
# Epoch [9/15], Iter [30,430] Loss:0.3974, average_loss: 0.4934
# Epoch [9/15], Iter [40,430] Loss:0.5801, average_loss: 0.4992
# Epoch [9/15], Iter [50,430] Loss:0.3932, average_loss: 0.5032
# Epoch [9/15], Iter [60,430] Loss:0.2403, average_loss: 0.4856
# Epoch [9/15], Iter [70,430] Loss:0.2991, average_loss: 0.5022
# Epoch [9/15], Iter [80,430] Loss:0.5857, average_loss: 0.5136
# Epoch [9/15], Iter [90,430] Loss:0.4649, average_loss: 0.5096
# Epoch [9/15], Iter [100,430] Loss:0.4096, average_loss: 0.5115
# Epoch [9/15], Iter [110,430] Loss:1.0430, average_loss: 0.5201
# Epoch [9/15], Iter [120,430] Loss:0.3258, average_loss: 0.5156
# Epoch [9/15], Iter [130,430] Loss:0.4565, average_loss: 0.5193
# Epoch [9/15], Iter [140,430] Loss:0.3208, average_loss: 0.5158
# Epoch [9/15], Iter [150,430] Loss:0.7251, average_loss: 0.5119
# Epoch [9/15], Iter [160,430] Loss:1.0007, average_loss: 0.5224
# Epoch [9/15], Iter [170,430] Loss:0.4441, average_loss: 0.5292
# Epoch [9/15], Iter [180,430] Loss:0.2819, average_loss: 0.5246
# Epoch [9/15], Iter [190,430] Loss:0.4625, average_loss: 0.5227
# Epoch [9/15], Iter [200,430] Loss:0.3857, average_loss: 0.5230
# Epoch [9/15], Iter [210,430] Loss:0.3610, average_loss: 0.5241
# Epoch [9/15], Iter [220,430] Loss:0.8540, average_loss: 0.5251
# Epoch [9/15], Iter [230,430] Loss:0.6742, average_loss: 0.5258
# Epoch [9/15], Iter [240,430] Loss:0.3397, average_loss: 0.5237
# Epoch [9/15], Iter [250,430] Loss:0.7514, average_loss: 0.5218
# Epoch [9/15], Iter [260,430] Loss:0.3942, average_loss: 0.5261
# Epoch [9/15], Iter [270,430] Loss:0.3437, average_loss: 0.5248
# Epoch [9/15], Iter [280,430] Loss:0.3322, average_loss: 0.5227
# Epoch [9/15], Iter [290,430] Loss:0.7948, average_loss: 0.5245
# Epoch [9/15], Iter [300,430] Loss:0.3303, average_loss: 0.5256
# Epoch [9/15], Iter [310,430] Loss:0.5056, average_loss: 0.5227
# Epoch [9/15], Iter [320,430] Loss:1.0009, average_loss: 0.5260
# Epoch [9/15], Iter [330,430] Loss:0.3035, average_loss: 0.5252
# Epoch [9/15], Iter [340,430] Loss:0.6103, average_loss: 0.5283
# Epoch [9/15], Iter [350,430] Loss:0.3947, average_loss: 0.5255
# Epoch [9/15], Iter [360,430] Loss:0.2270, average_loss: 0.5251
# Epoch [9/15], Iter [370,430] Loss:0.2892, average_loss: 0.5239
# Epoch [9/15], Iter [380,430] Loss:0.5696, average_loss: 0.5247
# Epoch [9/15], Iter [390,430] Loss:1.1472, average_loss: 0.5274
# Epoch [9/15], Iter [400,430] Loss:0.4821, average_loss: 0.5266
# Epoch [9/15], Iter [410,430] Loss:0.5585, average_loss: 0.5274
# Epoch [9/15], Iter [420,430] Loss:0.3902, average_loss: 0.5273
# Epoch [9/15], Iter [430,430] Loss:0.3598, average_loss: 0.5270
# Epoch [10/15], Iter [10,430] Loss:0.4691, average_loss: 0.5110
# Epoch [10/15], Iter [20,430] Loss:0.6247, average_loss: 0.5737
# Epoch [10/15], Iter [30,430] Loss:0.5805, average_loss: 0.5563
# Epoch [10/15], Iter [40,430] Loss:0.3754, average_loss: 0.5364
# Epoch [10/15], Iter [50,430] Loss:0.6206, average_loss: 0.5291
# Epoch [10/15], Iter [60,430] Loss:1.0262, average_loss: 0.5458
# Epoch [10/15], Iter [70,430] Loss:0.8514, average_loss: 0.5531
# Epoch [10/15], Iter [80,430] Loss:0.5056, average_loss: 0.5487
# Epoch [10/15], Iter [90,430] Loss:0.8002, average_loss: 0.5423
# Epoch [10/15], Iter [100,430] Loss:0.2752, average_loss: 0.5365
# Epoch [10/15], Iter [110,430] Loss:0.4803, average_loss: 0.5349
# Epoch [10/15], Iter [120,430] Loss:0.3474, average_loss: 0.5345
# Epoch [10/15], Iter [130,430] Loss:0.6726, average_loss: 0.5297
# Epoch [10/15], Iter [140,430] Loss:0.6309, average_loss: 0.5318
# Epoch [10/15], Iter [150,430] Loss:1.0209, average_loss: 0.5365
# Epoch [10/15], Iter [160,430] Loss:0.9325, average_loss: 0.5407
# Epoch [10/15], Iter [170,430] Loss:0.5134, average_loss: 0.5390
# Epoch [10/15], Iter [180,430] Loss:0.6032, average_loss: 0.5356
# Epoch [10/15], Iter [190,430] Loss:0.7180, average_loss: 0.5385
# Epoch [10/15], Iter [200,430] Loss:0.6910, average_loss: 0.5407
# Epoch [10/15], Iter [210,430] Loss:0.3402, average_loss: 0.5390
# Epoch [10/15], Iter [220,430] Loss:0.3430, average_loss: 0.5385
# Epoch [10/15], Iter [230,430] Loss:0.6169, average_loss: 0.5345
# Epoch [10/15], Iter [240,430] Loss:0.6051, average_loss: 0.5337
# Epoch [10/15], Iter [250,430] Loss:0.3292, average_loss: 0.5319
# Epoch [10/15], Iter [260,430] Loss:0.4813, average_loss: 0.5360
# Epoch [10/15], Iter [270,430] Loss:0.4770, average_loss: 0.5359
# Epoch [10/15], Iter [280,430] Loss:0.4895, average_loss: 0.5381
# Epoch [10/15], Iter [290,430] Loss:0.4311, average_loss: 0.5371
# Epoch [10/15], Iter [300,430] Loss:0.3773, average_loss: 0.5382
# Epoch [10/15], Iter [310,430] Loss:0.7650, average_loss: 0.5395
# Epoch [10/15], Iter [320,430] Loss:0.5746, average_loss: 0.5397
# Epoch [10/15], Iter [330,430] Loss:0.5583, average_loss: 0.5387
# Epoch [10/15], Iter [340,430] Loss:0.2275, average_loss: 0.5356
# Epoch [10/15], Iter [350,430] Loss:0.3570, average_loss: 0.5344
# Epoch [10/15], Iter [360,430] Loss:0.3256, average_loss: 0.5345
# Epoch [10/15], Iter [370,430] Loss:0.3301, average_loss: 0.5336
# Epoch [10/15], Iter [380,430] Loss:0.5776, average_loss: 0.5352
# Epoch [10/15], Iter [390,430] Loss:0.3616, average_loss: 0.5348
# Epoch [10/15], Iter [400,430] Loss:0.6538, average_loss: 0.5371
# Epoch [10/15], Iter [410,430] Loss:0.2534, average_loss: 0.5376
# Epoch [10/15], Iter [420,430] Loss:0.3685, average_loss: 0.5390
# Epoch [10/15], Iter [430,430] Loss:0.6369, average_loss: 0.5392
# Epoch [11/15], Iter [10,430] Loss:0.3876, average_loss: 0.5064
# Epoch [11/15], Iter [20,430] Loss:0.3984, average_loss: 0.5723
# Epoch [11/15], Iter [30,430] Loss:0.5155, average_loss: 0.5933
# Epoch [11/15], Iter [40,430] Loss:0.7752, average_loss: 0.5773
# Epoch [11/15], Iter [50,430] Loss:0.5576, average_loss: 0.5744
# Epoch [11/15], Iter [60,430] Loss:0.4169, average_loss: 0.5690
# Epoch [11/15], Iter [70,430] Loss:0.3418, average_loss: 0.5585
# Epoch [11/15], Iter [80,430] Loss:0.2915, average_loss: 0.5513
# Epoch [11/15], Iter [90,430] Loss:0.2570, average_loss: 0.5510
# Epoch [11/15], Iter [100,430] Loss:0.6158, average_loss: 0.5521
# Epoch [11/15], Iter [110,430] Loss:0.8024, average_loss: 0.5632
# Epoch [11/15], Iter [120,430] Loss:0.5107, average_loss: 0.5652
# Epoch [11/15], Iter [130,430] Loss:0.8395, average_loss: 0.5634
# Epoch [11/15], Iter [140,430] Loss:0.3806, average_loss: 0.5565
# Epoch [11/15], Iter [150,430] Loss:0.4301, average_loss: 0.5506
# Epoch [11/15], Iter [160,430] Loss:0.9077, average_loss: 0.5538
# Epoch [11/15], Iter [170,430] Loss:0.5680, average_loss: 0.5471
# Epoch [11/15], Iter [180,430] Loss:0.2953, average_loss: 0.5458
# Epoch [11/15], Iter [190,430] Loss:0.5196, average_loss: 0.5419
# Epoch [11/15], Iter [200,430] Loss:0.5508, average_loss: 0.5411
# Epoch [11/15], Iter [210,430] Loss:0.2883, average_loss: 0.5401
# Epoch [11/15], Iter [220,430] Loss:0.4201, average_loss: 0.5366
# Epoch [12/15], Iter [210,430] Loss:0.3925, average_loss: 0.5139
# Epoch [12/15], Iter [220,430] Loss:0.5252, average_loss: 0.5114
# Epoch [12/15], Iter [230,430] Loss:0.8502, average_loss: 0.5112
# Epoch [12/15], Iter [240,430] Loss:0.4597, average_loss: 0.5130
# Epoch [12/15], Iter [250,430] Loss:0.5978, average_loss: 0.5143
# Epoch [12/15], Iter [260,430] Loss:0.1997, average_loss: 0.5126
# Epoch [12/15], Iter [270,430] Loss:0.5896, average_loss: 0.5134
# Epoch [12/15], Iter [280,430] Loss:0.6363, average_loss: 0.5167
# Epoch [12/15], Iter [290,430] Loss:0.5481, average_loss: 0.5206
# Epoch [12/15], Iter [300,430] Loss:0.3640, average_loss: 0.5199
# Epoch [12/15], Iter [310,430] Loss:0.3146, average_loss: 0.5208
# Epoch [12/15], Iter [320,430] Loss:1.2432, average_loss: 0.5227
# Epoch [12/15], Iter [330,430] Loss:0.2979, average_loss: 0.5224
# Epoch [12/15], Iter [340,430] Loss:0.8824, average_loss: 0.5231
# Epoch [12/15], Iter [350,430] Loss:0.5654, average_loss: 0.5217
# Epoch [12/15], Iter [360,430] Loss:0.4243, average_loss: 0.5202
# Epoch [12/15], Iter [370,430] Loss:0.5737, average_loss: 0.5223
# Epoch [12/15], Iter [380,430] Loss:0.6191, average_loss: 0.5266
# Epoch [12/15], Iter [390,430] Loss:0.4299, average_loss: 0.5261
# Epoch [12/15], Iter [400,430] Loss:0.7275, average_loss: 0.5276
# Epoch [12/15], Iter [410,430] Loss:0.4465, average_loss: 0.5291
# Epoch [12/15], Iter [420,430] Loss:0.5034, average_loss: 0.5302
# Epoch [12/15], Iter [430,430] Loss:0.6354, average_loss: 0.5290
# Epoch [13/15], Iter [10,430] Loss:0.7036, average_loss: 0.4991
# Epoch [13/15], Iter [20,430] Loss:0.5482, average_loss: 0.5314
# Epoch [13/15], Iter [30,430] Loss:0.3951, average_loss: 0.5359
# Epoch [13/15], Iter [40,430] Loss:0.4558, average_loss: 0.5174
# Epoch [13/15], Iter [50,430] Loss:0.4945, average_loss: 0.5083
# Epoch [13/15], Iter [60,430] Loss:0.4388, average_loss: 0.5147
# Epoch [13/15], Iter [70,430] Loss:0.3883, average_loss: 0.5158
# Epoch [13/15], Iter [80,430] Loss:0.4705, average_loss: 0.5197
# Epoch [13/15], Iter [90,430] Loss:0.3227, average_loss: 0.5142
# Epoch [13/15], Iter [100,430] Loss:0.2984, average_loss: 0.5115
# Epoch [13/15], Iter [110,430] Loss:0.5400, average_loss: 0.5070
# Epoch [13/15], Iter [120,430] Loss:0.9459, average_loss: 0.5109
# Epoch [13/15], Iter [130,430] Loss:0.7190, average_loss: 0.5119
# Epoch [13/15], Iter [140,430] Loss:0.3941, average_loss: 0.5166
# Epoch [13/15], Iter [150,430] Loss:0.2932, average_loss: 0.5157
# Epoch [13/15], Iter [160,430] Loss:0.3594, average_loss: 0.5159
# Epoch [13/15], Iter [170,430] Loss:0.7614, average_loss: 0.5144
# Epoch [13/15], Iter [180,430] Loss:0.5328, average_loss: 0.5194
# Epoch [13/15], Iter [190,430] Loss:0.3094, average_loss: 0.5165
# Epoch [13/15], Iter [200,430] Loss:0.3263, average_loss: 0.5152
# Epoch [13/15], Iter [210,430] Loss:0.4042, average_loss: 0.5155
# Epoch [13/15], Iter [220,430] Loss:0.3715, average_loss: 0.5144
# Epoch [13/15], Iter [230,430] Loss:0.4335, average_loss: 0.5154
# Epoch [13/15], Iter [240,430] Loss:0.5544, average_loss: 0.5149
# Epoch [13/15], Iter [250,430] Loss:0.5667, average_loss: 0.5145
# Epoch [13/15], Iter [260,430] Loss:0.5812, average_loss: 0.5136
# Epoch [13/15], Iter [270,430] Loss:0.4227, average_loss: 0.5161
# Epoch [13/15], Iter [280,430] Loss:0.2218, average_loss: 0.5155
# Epoch [13/15], Iter [290,430] Loss:0.6374, average_loss: 0.5206
# Epoch [13/15], Iter [300,430] Loss:0.5900, average_loss: 0.5200
# Epoch [13/15], Iter [310,430] Loss:0.4366, average_loss: 0.5178
# Epoch [13/15], Iter [320,430] Loss:0.4197, average_loss: 0.5176
# Epoch [13/15], Iter [330,430] Loss:0.6429, average_loss: 0.5171
# Epoch [13/15], Iter [340,430] Loss:0.3682, average_loss: 0.5167
# Epoch [13/15], Iter [350,430] Loss:0.2901, average_loss: 0.5202
# Epoch [13/15], Iter [360,430] Loss:0.5024, average_loss: 0.5203
# Epoch [13/15], Iter [370,430] Loss:0.4853, average_loss: 0.5193
# Epoch [13/15], Iter [380,430] Loss:0.5569, average_loss: 0.5189
# Epoch [13/15], Iter [390,430] Loss:0.4026, average_loss: 0.5200
# Epoch [13/15], Iter [400,430] Loss:0.4480, average_loss: 0.5198
# Epoch [13/15], Iter [410,430] Loss:0.4808, average_loss: 0.5229
# Epoch [13/15], Iter [420,430] Loss:0.6276, average_loss: 0.5237
# Epoch [13/15], Iter [430,430] Loss:0.3189, average_loss: 0.5216
# Epoch [14/15], Iter [10,430] Loss:0.4445, average_loss: 0.5558
# Epoch [14/15], Iter [20,430] Loss:0.4440, average_loss: 0.4916
# Epoch [14/15], Iter [30,430] Loss:0.2588, average_loss: 0.4807
# Epoch [14/15], Iter [40,430] Loss:0.3077, average_loss: 0.4920
# Epoch [14/15], Iter [50,430] Loss:0.2726, average_loss: 0.5047
# Epoch [14/15], Iter [60,430] Loss:0.6053, average_loss: 0.5096
# Epoch [14/15], Iter [70,430] Loss:0.5452, average_loss: 0.5167
# Epoch [14/15], Iter [80,430] Loss:0.4498, average_loss: 0.5035
# Epoch [14/15], Iter [90,430] Loss:0.4330, average_loss: 0.5164
# Epoch [14/15], Iter [100,430] Loss:0.4538, average_loss: 0.5152
# Epoch [14/15], Iter [110,430] Loss:0.7331, average_loss: 0.5164
# Epoch [14/15], Iter [120,430] Loss:0.8312, average_loss: 0.5187
# Epoch [14/15], Iter [130,430] Loss:0.6623, average_loss: 0.5179
# Epoch [14/15], Iter [140,430] Loss:0.2980, average_loss: 0.5126
# Epoch [15/15], Iter [130,430] Loss:0.5359, average_loss: 0.5257
# Epoch [15/15], Iter [140,430] Loss:0.4308, average_loss: 0.5187
# Epoch [15/15], Iter [150,430] Loss:0.4163, average_loss: 0.5153
# Epoch [15/15], Iter [160,430] Loss:0.3296, average_loss: 0.5139
# Epoch [15/15], Iter [170,430] Loss:0.5866, average_loss: 0.5181
# Epoch [15/15], Iter [180,430] Loss:0.4990, average_loss: 0.5136
# Epoch [15/15], Iter [190,430] Loss:0.4234, average_loss: 0.5209
# Epoch [15/15], Iter [200,430] Loss:0.3225, average_loss: 0.5178
# Epoch [15/15], Iter [210,430] Loss:0.3605, average_loss: 0.5171
# Epoch [15/15], Iter [220,430] Loss:0.6768, average_loss: 0.5184
# Epoch [15/15], Iter [230,430] Loss:0.4258, average_loss: 0.5185
# Epoch [15/15], Iter [240,430] Loss:0.9964, average_loss: 0.5184
# Epoch [15/15], Iter [250,430] Loss:0.5669, average_loss: 0.5201
# Epoch [15/15], Iter [260,430] Loss:0.8818, average_loss: 0.5275
# Epoch [15/15], Iter [270,430] Loss:0.3864, average_loss: 0.5250
# Epoch [15/15], Iter [280,430] Loss:0.5472, average_loss: 0.5265
# Epoch [15/15], Iter [290,430] Loss:0.9024, average_loss: 0.5283
# Epoch [15/15], Iter [300,430] Loss:0.3498, average_loss: 0.5266
# Epoch [15/15], Iter [310,430] Loss:0.5785, average_loss: 0.5248
# Epoch [15/15], Iter [320,430] Loss:0.9396, average_loss: 0.5268
# Epoch [15/15], Iter [330,430] Loss:0.4797, average_loss: 0.5247
# Epoch [15/15], Iter [340,430] Loss:0.3648, average_loss: 0.5223
# Epoch [15/15], Iter [350,430] Loss:0.4186, average_loss: 0.5246
# Epoch [15/15], Iter [360,430] Loss:0.2440, average_loss: 0.5262
# Epoch [15/15], Iter [370,430] Loss:0.5438, average_loss: 0.5263
# Epoch [15/15], Iter [380,430] Loss:0.4460, average_loss: 0.5265
# Epoch [15/15], Iter [390,430] Loss:0.3586, average_loss: 0.5262
# Epoch [15/15], Iter [400,430] Loss:0.4986, average_loss: 0.5266
# Epoch [15/15], Iter [410,430] Loss:0.5277, average_loss: 0.5275
# Epoch [15/15], Iter [420,430] Loss:0.6384, average_loss: 0.5281
# Epoch [15/15], Iter [430,430] Loss:0.6578, average_loss: 0.5266

# %% [markdown]
# ### Step 5. Inference

# %% [markdown]
# ### Step 5-1. Inference (Visualizing)
# - The below code is for visualizing your results.
# - Check out!

# %%
cd /root
# Out:
# /root

# %%
# NEW
## Visualizing the bouding box image
from misc.lab07.util import *

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

Color = [[0, 0, 0],
                    [128, 0, 0],
                    [0, 128, 0],
                    [128, 128, 0],
                    [0, 0, 128],
                    [128, 0, 128]]

def visualize(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    
    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0.1)
    
    for i, box in enumerate(boxes):
        
        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        result.append([(x1, y1), (x2, y2), SMALL_VOC_CLASSES[cls_index], prob])
        
    img = np.zeros((h, w, 3), np.bool)
    img = img + image[:,:,::-1]
        
    for left_up,right_bottom,class_name,prob in result:
        color = Color[SMALL_VOC_CLASSES.index(class_name)]
        cv2.rectangle(img, left_up, right_bottom, color, 2)
        label = class_name+str(round(prob,2))
        text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
        p1 = (left_up[0], left_up[1]- text_size[1])
        cv2.rectangle(img, (p1[0] - 2//2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]), color, -1)
        cv2.putText(img, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255,255,255), 1, 8)
        print(label) # print label of all boxes!
    
    plt.imshow(img)
    
model.eval()
# Out:
# YOLO(
#   (pre_train_net): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): LeakyReLU(negative_slope=0.01)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): LeakyReLU(negative_slope=0.01)
#     (10): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (11): LeakyReLU(negative_slope=0.01)
#     (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): LeakyReLU(negative_slope=0.01)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (16): LeakyReLU(negative_slope=0.01)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): LeakyReLU(negative_slope=0.01)
#     (19): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (20): LeakyReLU(negative_slope=0.01)
#     (21): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): LeakyReLU(negative_slope=0.01)
#     (23): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (24): LeakyReLU(negative_slope=0.01)
#     (25): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): LeakyReLU(negative_slope=0.01)
#     (27): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (28): LeakyReLU(negative_slope=0.01)
#     (29): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (30): LeakyReLU(negative_slope=0.01)
#     (31): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#     (32): LeakyReLU(negative_slope=0.01)
#     (33): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): LeakyReLU(negative_slope=0.01)
#     (35): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (36): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#     (37): LeakyReLU(negative_slope=0.01)
#     (38): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (39): LeakyReLU(negative_slope=0.01)
#   )
#   (post_net): Sequential(
#     (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01)
#   )
#   (FC1): Sequential(
#     (0): Linear(in_features=50176, out_features=4096, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.5, inplace=False)
#   )
#   (FC2): Sequential(
#     (0): Linear(in_features=4096, out_features=1470, bias=True)
#   )
# )

# %% [markdown]
# - You can check various results by chaning the name of files.

# %%
visualize(model, './misc/lab07/Generate_dataset/images/004199.jpg')
# Out:
# aeroplane0.5

# %%
visualize(model, './misc/lab07/Generate_dataset/images/006034.jpg')
# Out:
# car0.59

# %% [markdown]
# ### Step 6-2. Inference (mAP)
# - The below code is for checkout your network performance,
# - By using this code, your network prediction is saved in Generate_dataset directory
# - Then, %run ./misc/lab07/Generate_dataset/main.py
# - After a few seconds, the mAP is printed.
# - **Note that if your code is correct, the mAP will be over 69.**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')
os.makedirs('predicted', exist_ok=True)

def write(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    
    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0)
    
    
    txt_file = open(os.path.join('predicted', os.path.basename(path)[:-4]+'.txt'), 'w')
    
    for i, box in enumerate(boxes):
        
        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        txt_file.write(str(SMALL_VOC_CLASSES[cls_index])+' '+'%.6f'%(prob)+' '+str(x1)+' '+str(y1)+' '+str(x2)+' '+str(y2))
        txt_file.write('\n')
    txt_file.close()
    
import glob

model.eval()
img_names = glob.glob('./misc/lab07/Generate_dataset/images/*')

for i, file_name in enumerate(img_names):
    write(model, file_name)
    if i % 500 == 0:
        print(i)
# Out:
# 0
# 500
# 1000

# %%
# %run ./misc/lab07/Generate_dataset/main.py
# Out:
# 64.81% = aeroplane AP
# 69.82% = bicycle AP
# 65.33% = bus AP
# 68.21% = car AP
# 75.47% = cat AP
# 76.69% = dog AP
# mAP = 70.05%

# %% [markdown]
# ### *References*
# [1] https://www.pyimagesearch.com/2018/05/14/a-gentle-guide-to-deep-learning-object-detection/
#
# [2] https://github.com/Cartucho/mAP
